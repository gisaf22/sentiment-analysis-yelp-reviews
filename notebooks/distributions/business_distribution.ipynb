# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
reviews_2022_df = pd.read_parquet("../yelp_reviews.parquet")
businesses_df = pd.read_json('../yelp_dataset/yelp_academic_dataset_business.json', lines=True)

# %%
reviews_2022_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %% [markdown]
# #### Total number of unique businesses in 2022

# %%
# Number of businesses with reviews
len(reviews_2022_df.business_id.unique())
# Out:
# 150346

# %% [markdown]
# #### Distribution of number of reviews per business in 2022

# %%
# Count reviews per business, sorted descending
review_counts = reviews_2022_df['business_id'].value_counts(ascending=False)

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(review_counts, bins=50)  # Adjust bins as needed
plt.title("Distribution of Reviews per Business (2022)")
plt.xlabel("Number of Reviews per Business")
plt.ylabel("Number of Businesses")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Reviews in 2022 are heavily right-tailed

# %%
reviews_2022_df['business_id'].value_counts().describe()
# Out:
# count    150346.000000
# mean         46.494619
# std         124.519061
# min           5.000000
# 25%           8.000000
# 50%          15.000000
# 75%          38.000000
# max        7673.000000
# Name: count, dtype: float64

# %% [markdown]
# #### Total number of unique businesses in entire dataset (2015-2022)

# %%
businesses_df.shape[0]
# Out:
# 150346

# %%
businesses_df[businesses_df.name.str.strip().str.lower() == 'datz']
# Out:
#                    business_id  name                        address  \
# 82231   4U8tToDb49xGDzWfn5TPaA  Datz  6264 Winthrop Town Centre Ave
# 137449  QHWYlmVbLC3K6eglWoHVvA  Datz             2616 S MacDill Ave
#
#              city state postal_code   latitude  longitude  stars  \
# 82231   Riverview    FL       33578  27.892032 -82.317037    3.5
# 137449      Tampa    FL       33629  27.921942 -82.493253    4.0
#
#         review_count  is_open  \
# 82231            185        1
# 137449          3260        1
#
#                                                attributes  \
# 82231   {'RestaurantsTableService': 'True', 'BusinessA...
# 137449  {'RestaurantsAttire': 'u'casual'', 'BusinessAc...
#
#                                                categories  \
# 82231   Salad, Burgers, Bars, Nightlife, Restaurants, ...
# 137449  Burgers, Bars, Restaurants, American (Traditio...
#
#                                                     hours
# 82231   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 137449  {'Monday': '0:0-0:0', 'Tuesday': '7:0-22:0', '...

# %% [markdown]
# #### Total number of unique businesses in entire dataset (2015-2022) per state

# %%
businesses_df['state'].value_counts().sort_values(ascending=False)
# Out:
# state
# PA     34039
# FL     26330
# TN     12056
# IN     11247
# MO     10913
# LA      9924
# AZ      9912
# NJ      8536
# NV      7715
# AB      5573
# CA      5203
# ID      4467
# DE      2265
# IL      2145
# TX         4
# CO         3
# WA         2
# HI         2
# MA         2
# NC         1
# UT         1
# MT         1
# MI         1
# SD         1
# XMS        1
# VI         1
# VT         1
# Name: count, dtype: int64

# %% [markdown]
# #### States with the most number of reviews

# %%
businesses_df.groupby('state')['review_count'].sum().sort_values(ascending=False)
# Out:
# state
# PA     1540790
# FL     1119926
# LA      743176
# TN      598195
# MO      483897
# IN      472565
# AZ      412639
# NV      409950
# CA      339637
# NJ      249837
# ID      152086
# AB      105477
# DE       67370
# IL       49676
# MA          43
# SD          42
# TX          33
# HI          32
# CO          30
# NC          29
# UT          19
# WA          19
# VI          10
# VT          10
# MI           9
# MT           6
# XMS          5
# Name: review_count, dtype: int64

# %% [markdown]
# #### Businesses with the most reviews

# %%
top_businesses = businesses_df.sort_values('review_count', ascending=False).head(50)
top_businesses[['name', 'city', 'state', 'categories', 'review_count', 'stars']].head()
# Out:
#                                       name          city state  \
# 113731                   Acme Oyster House   New Orleans    LA
# 112552                        Oceana Grill   New Orleans    LA
# 91757   Hattie B’s Hot Chicken - Nashville     Nashville    TN
# 143157             Reading Terminal Market  Philadelphia    PA
# 147081          Ruby Slipper - New Orleans   New Orleans    LA
#
#                                                categories  review_count  stars
# 113731  Live/Raw Food, Seafood, Restaurants, Cajun/Creole          7568    4.0
# 112552  Restaurants, Seafood, Cajun/Creole, Breakfast ...          7400    4.0
# 91757   American (Traditional), Chicken Shop, Southern...          6093    4.5
# 143157  Candy Stores, Shopping, Department Stores, Fas...          5721    4.5
# 147081  Restaurants, American (Traditional), American ...          5193    4.5

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.min_rows', 50)
businesses_df.groupby(['name', 'business_id'])['review_count'].sum().reset_index().sort_values('review_count', ascending=False)
# Out:
#                                        name             business_id  \
# 3288                      Acme Oyster House  _ab50qdWOk0DdB6XOrBitw
# 90505                          Oceana Grill  ac1AeYqs8Z4_e2X5M3if2A
# 56813    Hattie B’s Hot Chicken - Nashville  GXFMD0Z4jEVZBCsbPf4CTQ
# 104577              Reading Terminal Market  ytynqOUb3hjKeJfRj5Tshw
# 109186           Ruby Slipper - New Orleans  oBNrLz4EDhiscSlbOl8uAw
# 85017                   Mother's Restaurant  iSRTaT9WngzB8JJ2YKJUig
# 109007                          Royal House  VQcCL9PiNL_wkGf-uF3fjg
# 30402                    Commander's Palace  _C7QiQQc47AOEv4PE3Kong
# 76073                                  Luke  GBTPC53ZrG1ZBY3DT8Mbcw
# 29716                                Cochon  6a4gLLFSgr-Q6CZXDLzBGQ
# 94931                  Pat's King of Steaks  PP3BBaVxZLcJU54uP_wL6Q
# 15482                   Biscuit Love: Gulch  1b5mnK8bMnnju_cvU65GqQ
# 94272                    Pappy's Smokehouse  I_3LMZ_1m2mzR0oLIOePIg
# 45785       Felix's Restaurant & Oyster Bar  VaO-VW3e1kARkU9bP1E7Fw
# 54846                            Gumbo Shop  qb28j-FNX1_6xm7u372TZA
# 29719                        Cochon Butcher  gTC8IQ_i8zXytWSly3Ttvg
# 75131                            Los Agaves  yPSejq3_erxo9zdVYTBnZA
# 146941            Willie Mae's Scotch House  VVH6k9-ycttH3TV_lk5WfQ
# 51132                         Geno's Steaks  IkY2ticzHEn4QFn8hQLSWg
# 53300        Grand Sierra Resort and Casino  wz8ZPfySQczcPgSyd33-HQ
# 34844                                  Datz  QHWYlmVbLC3K6eglWoHVvA
# 41867                                El Vez  9PZxjhTIU7OgPIzuGi89Ew
# 38779            Drago's Seafood Restaurant  DcBLYSvOuWcNReolRVr12A
# 31048                          Coop's Place  XnQ84ylyAZwh-XfHGGNBbQ
# 149229                                Zahav  ctHjyadbDQAtUFfkcAFEHw
# ...                                     ...                     ...
# 110719                  Sally Beauty Supply  MOiTfBxpbGHsp_HRqKP5iw
# 16091                         Blu Salon Co.  L4MD197SU2J0VgXJ-sxPBg
# 34279                           Dairy Queen  3B9vzbshfvEMu_4HZnXmLQ
# 138408   Tucson Professional Steam Cleaners  1nFf-smaCqo3G2ANiJRVzw
# 16086                           Blu Fitness  Z0g_34yaTcVVKzfT_IYYNA
# 116872                  Sol Hot Yoga Studio  UHhy547ZjMLP-vflwpE9AA
# 49472                                Fringe  BAxyMeWfg1w_HEaTZHADxg
# 78898                     Marple Automotive  4F0ICsIp3I8J3hf3EMNXFQ
# 93927                     Papa John's Pizza  5CKV11q5paF8CyjbfmK0Pg
# 138416                Tucson Reptile Rescue  _7asVsEzx1kdkNxvdxCQbw
# 84428                 Monkey's Tree Service  tbIflMm0UD-kSSHv4Ku5-A
# 34291                           Dairy Queen  8Q26tswK7ZVmRkNGHXCOMQ
# 16067                       Blossoming Yoga  WVbXR1mMw4-G5pzBGWIFsg
# 16066                      Blossom Painting  7pFRCvND5nhNx-EcBC0UAg
# 71073                            La Villita  oHEDOoEtevNC81BtCOyaLA
# 16063                    Blossom Hair Salon  q4yGJn2z62d6OIjIdGb-nA
# 84415                      Monkey Fish Toys  i8JppYIoqr8zmNllEkcQWw
# 138425                Tucson Septic Pumping  Lt9TpGbLZ08IP1QRB2gIlA
# 110710                  Sally Beauty Supply  Agb4aIkeo6UpU3uLifTVwA
# 78892   Maro Brothers' Discount Liquor Mart  TbecggQ5Oj_XME8Xbwhpdw
# 110708                  Sally Beauty Supply  8vnMMI6u-INhQOEPWAHpEA
# 138431                      Tucson Speedway  k2LAjBpuX-2oTgIKmUbJ6Q
# 138432                 Tucson Stained Glass  b9fO_23VAH3dH7o3L8siLw
# 16049               Blooms & Linen Boutique  2NiJpmJsTrprmBz95N9-8w
# 85732                       Multi State Tax  McAHyTjlyIgY1wJ5Nug8qg
#
#         review_count
# 3288            7568
# 90505           7400
# 56813           6093
# 104577          5721
# 109186          5193
# 85017           5185
# 109007          5070
# 30402           4876
# 76073           4554
# 29716           4421
# 94931           4250
# 15482           4207
# 94272           3999
# 45785           3966
# 54846           3902
# 29719           3837
# 75131           3834
# 146941          3582
# 51132           3401
# 53300           3345
# 34844           3260
# 41867           3187
# 38779           3160
# 31048           3157
# 149229          3065
# ...              ...
# 110719             5
# 16091              5
# 34279              5
# 138408             5
# 16086              5
# 116872             5
# 49472              5
# 78898              5
# 93927              5
# 138416             5
# 84428              5
# 34291              5
# 16067              5
# 16066              5
# 71073              5
# 16063              5
# 84415              5
# 138425             5
# 110710             5
# 78892              5
# 110708             5
# 138431             5
# 138432             5
# 16049              5
# 85732              5
#
# [150346 rows x 3 columns]

# %% [markdown]
# #### Businesses with the most reviews in 2022

# %%
reviews_businesses_2022_df = reviews_2022_df.merge(
    businesses_df,
    on="business_id",
    how="left",  # keep all reviews, even if business info missing
    suffixes=("_review", "_business")
)

# %%
top_businesses = (
    reviews_businesses_2022_df
    .groupby(['business_id', 'name'])                # group by unique business
    .size()                                          # count reviews per business
    .reset_index(name='review_count')                # rename the count column
    .sort_values('review_count', ascending=False)    # sort descending
)

# View the top 10
top_businesses.head(10)
# Out:
#                   business_id  \
# 11479  ac1AeYqs8Z4_e2X5M3if2A
# 1297   3IUg1tfMbxq6a10WSiK9wQ
# 15751  p76UGLhyXLxUZij1MUsFBA
# 18665  ytynqOUb3hjKeJfRj5Tshw
# 4945   FEXhWNCMkv22qG04E83Qjg
# 15465  oBNrLz4EDhiscSlbOl8uAw
# 8732   SJIQFKTW6uUsOo29w9IHxw
# 9963   WVNkMz4sEl35swjVtKHOFw
# 9617   VItkA7pL82rCZdxHH8vBGA
# 8807   SZU9c8V2GuREDN5KgyHFJw
#
#                                                                   name  \
# 11479                                                     Oceana Grill
# 1297                                      Elite Experience: Bright Ice
# 15751                             2022 Boba and Badges with Ni Hao Tea
# 18665                                          Reading Terminal Market
# 4945                                                     Café Du Monde
# 15465                                       Ruby Slipper - New Orleans
# 8732                                                           Mambo's
# 9963                                        Alessia Patisserie & Cafe
# 9617   Elite Experience: Lunch Training Preview at honeygrow Wynnewood
# 8807                                   Santa Barbara Shellfish Company
#
#        review_count
# 11479            56
# 1297             43
# 15751            41
# 18665            30
# 4945             28
# 15465            27
# 8732             25
# 9963             24
# 9617             24
# 8807             23

# %%
businesses_df[businesses_df.name == 'Oceana Grill']
# Out:
#                    business_id          name       address         city state  \
# 112552  ac1AeYqs8Z4_e2X5M3if2A  Oceana Grill  739 Conti St  New Orleans    LA
#
#        postal_code   latitude  longitude  stars  review_count  is_open  \
# 112552       70130  29.956231 -90.067563    4.0          7400        1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        attributes  \
# 112552  {'RestaurantsGoodForGroups': 'True', 'RestaurantsDelivery': 'True', 'RestaurantsPriceRange2': '2', 'RestaurantsAttire': ''casual'', 'GoodForKids': 'True', 'BusinessAcceptsCreditCards': 'True', 'BYOBCorkage': ''no'', 'RestaurantsTableService': 'True', 'RestaurantsReservations': 'True', 'Alcohol': 'u'full_bar'', 'OutdoorSeating': 'True', 'BusinessParking': '{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}', 'HasTV': 'True', 'BYOB': 'False', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'WheelchairAccessible': 'True', 'HappyHour': 'True', 'NoiseLevel': 'u'average'', 'GoodForMeal': '{'dessert': None, 'latenight': None, 'lunch': True, 'dinner': True, 'brunch': None, 'breakfast': None}', 'Ambience': '{'touristy': True, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': True}', 'Caters': 'True', 'ByAppointmentOnly': 'False', 'DriveThru': 'False', 'DogsAllowed': 'True', 'WiFi': 'u'free''}
#
#                                                     categories  \
# 112552  Restaurants, Seafood, Cajun/Creole, Breakfast & Brunch
#
#                                                                                                                                                               hours
# 112552  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'Wednesday': '8:0-1:0', 'Thursday': '8:0-1:0', 'Friday': '8:0-1:0', 'Saturday': '8:0-1:0', 'Sunday': '8:0-1:0'}
