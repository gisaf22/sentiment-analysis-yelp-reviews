# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from collections import Counter

from gensim.models import Word2Vec
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

import gensim.downloader as api

from sentence_transformers import SentenceTransformer
import torch

# %%
from IPython.display import display

# Permanently set options for the current session
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 50)
pd.set_option('display.width', 1000)

# %%
# Path to your Parquet file
parquet_file_path = 'processed/processed_reviews.parquet'

# Read the Parquet file into a DataFrame
reviews_df = pd.read_parquet(parquet_file_path)

# Display the first few rows of the DataFrame
reviews_df.head()
# Out:
#                 review_id             business_id  stars                                         categories                date                                               text                                             lemmas  num_lemmas  month  review_length  avg_word_length
# 0  mG1FavLfA5j2L83sCZ3rFg  drTZrkbpSoJgwKETlFbc3w    1.0  Shopping, Musical Instrument Services, Musical... 2022-01-01 15:47:07  I bought a Fender 1966 Telecaster that the sal...  buy fender telecaster salesperson tell origina...          50      1            641              5.0
# 1  WMpnr1XBJ5U38rfSdErhJQ  jyxHti29yWdYR00Itt1A2w    5.0                         Restaurants, Mediterranean 2022-01-02 03:49:01  This is our go to for take out when I visit my...  visit son restaurant desert home food authenti...          14      1            208              4.0
# 2  99EMi0lRhdmylbG0soaf9w  Jo4ei-c-5H53IxZxAVf1jQ    5.0  Hair Salons, Men's Hair Salons, Barbers, Beaut... 2022-01-03 03:17:03  Danielle did a great job!  She listened and cu...  danielle great job listen cut hair way request...          24      1            278              4.0
# 3  Qs4z8e7hCoU9EzRKD9rGPQ  YT5CjacTllBtvMaMJS3IbA    1.0  Hotels & Travel, Hotels, Venues & Event Spaces... 2022-01-05 15:55:59  We saw a lot of roaches in the bathroom when w...  see lot roach bathroom wake bed large dark sta...          38      1            514              4.0
# 4  SXZ2Nw9UGAgPlXJsju9fFA  9MHe5jAym2d8VhT_NbCRyw    2.0                         Restaurants, Chinese, Thai 2022-01-06 03:59:21  We  Ordered pork fried rice and beef chow mei ...  order pork fry rice beef chow mei fun teriyaki...          16      1            148              5.0

# %% [markdown]
# ### Embeddings
# Word embeddings are representations that capture context and similarities in a vector space. Semantically similar words would have similar representations in that space. I will explore multiple embeddings models and compare semantic relationships uncovered by each.

# %% [markdown]
# #### i. Gensim Word2Vec (trained on our lemmas)
# Each review has its own context window instead of a flat list of all lemmas. Uses local context(words around word) to predict word embedding.

# %% [markdown]
# Each input to the model must be a list of strings, in our case, lemmas(tokens). Therefore, we need to split out lemmas column, which is a space-separated string.

# %%
# Word2Vec expects a list of comma-separated tokens
reviews_df['lemma_tokens'] = reviews_df.lemmas.apply(lambda l: l.split())
reviews_df['lemma_tokens'].head()
# Out:
# 0    [buy, fender, telecaster, salesperson, tell, o...
# 1    [visit, son, restaurant, desert, home, food, a...
# 2    [danielle, great, job, listen, cut, hair, way,...
# 3    [see, lot, roach, bathroom, wake, bed, large, ...
# 4    [order, pork, fry, rice, beef, chow, mei, fun,...
# Name: lemma_tokens, dtype: object

# %%
model = Word2Vec(sentences=reviews_df.lemma_tokens, vector_size=200, window=5, min_count=5, workers=8)

# %%
words = model.wv.index_to_key
len(words)
# Out:
# 10192

# %% [markdown]
# We can find similarity between two words in the vocabulary aka the cosine distance between their word vectors.

# %%
model.wv.similarity('tai', 'ziti')
# Out:
# 0.82272756

# %% [markdown]
# Or find words in the vocabulary similar to a given word from the vocabulary.

# %%
# word similarity
model.wv.most_similar("saw", topn=10)
# Out:
# [('landscaping', 0.9525336027145386),
#  ('repairman', 0.9469929337501526),
#  ('bullshit', 0.9467512965202332),
#  ('walker', 0.9459699392318726),
#  ('generator', 0.945475161075592),
#  ('nonsense', 0.94309401512146),
#  ('faulty', 0.942777156829834),
#  ('jefferson', 0.9417145252227783),
#  ('steering', 0.9362192749977112),
#  ('settlement', 0.9358218908309937)]

# %% [markdown]
# #### Visualize word embeddings
# We can visualize clusters of similar words and observe words that are similar in context or semantically.

# %%
# From Stanford's notebook, https://web.stanford.edu/class/cs224n/materials/Gensim%20word%20vector%20visualization.html
pca = PCA(n_components=2, random_state=42)
def display_pca_scatterplot(model, sample=0):
    if sample > 0:
        words = np.random.choice(model.wv.index_to_key, sample)
    else:
        words = [word for word in model.wv.index_to_key]
        
    word_vectors = np.array(model.wv[words])

    twodim = pca.fit_transform(word_vectors)
    
    plt.figure(figsize=(10,8))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r', alpha=0.7)
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.02, y+0.02, word, fontsize=9)
    plt.title("Random Sample of Word2Vec Vocabulary (2D PCA)")
    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.show()

# %%
display_pca_scatterplot(model, sample=20)

# %% [markdown]
# #### ii. Pre-trained embeddings models
# We'll also evaluate a couple of pretrained embeddings models.

# %% [markdown]
# #### a. Gensim pretrained models

# %%
# Gensim Glove pretrained models
[model for model in api.info()['models'].keys() if 'glove' in model]
# Out:
# ['glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200']

# %% [markdown]
# 'glove-wiki-gigaword-200' pretrained model

# %%
glove_wiki = api.load('glove-wiki-gigaword-200')

# %%
glove_wiki.most_similar('saw')
# Out:
# [('came', 0.7834239602088928),
#  ('seeing', 0.7421119809150696),
#  ('seen', 0.7344871163368225),
#  ('coming', 0.7182721495628357),
#  ('when', 0.7094781398773193),
#  ('went', 0.6966612339019775),
#  ('took', 0.6953846216201782),
#  ('back', 0.677486777305603),
#  ('did', 0.673191249370575),
#  ('brought', 0.67198646068573)]

# %% [markdown]
# 'glove-twitter-200' pretrained model

# %%
glove_twitter = api.load('glove-twitter-200')

# %%
glove_twitter.most_similar('saw')
# Out:
# [('thought', 0.7656410336494446),
#  ('seen', 0.7622860074043274),
#  ('said', 0.7154862880706787),
#  ('looked', 0.7126939296722412),
#  ('knew', 0.7120527029037476),
#  ('did', 0.706375002861023),
#  ('watched', 0.7059610486030579),
#  ('seeing', 0.6991493701934814),
#  ('see', 0.6918333768844604),
#  ('remember', 0.689777135848999)]

# %%
all_lemmas = [lemma for tokens in reviews_df.lemma_tokens for lemma in tokens]
unique_lemmas = list(set(all_lemmas))
lemmas_in_glove_wiki = [lemma for lemma in unique_lemmas if lemma in glove_wiki]
lemmas_in_glove_twitter = [lemma for lemma in unique_lemmas if lemma in glove_twitter]

print(len(unique_lemmas))
print(len(lemmas_in_glove_wiki))
print(len(lemmas_in_glove_twitter))
# Out:
# 30041
# 24393
# 24993

# %% [markdown]
# ### iii. Contextualized Transformer-based Embeddings

# %% [markdown]
# #### BERT

# %%
def get_review_embeddings_contextual(lemmas_string):
    """
    Encode one review (space-separated lemmas) into contextual embeddings per token.
    Returns dict {token: embedding_tensor}.
    """
    tokens = lemmas_string.split()
    embeddings = model.encode(tokens, convert_to_tensor=True)  # [num_tokens, 384]
    return dict(zip(tokens, embeddings))

# Apply to a single review
embeddings = get_review_embeddings_contextual(reviews_df['lemmas'][0])
print("Token embeddings shape:", embeddings[list(embeddings.keys())[0]].shape)

# Optional: average for a single review vector
def review_vector(tokens_embeddings):
    return torch.stack(list(tokens_embeddings.values())).mean(dim=0)

review_vec = review_vector(embeddings)
print("Review embedding shape:", review_vec.shape)
# Out:
# Token embeddings shape: torch.Size([384])
# Review embedding shape: torch.Size([384])

# %%
reviews_df['lemma_embeddings'] = reviews_df['lemmas'].apply(get_review_embeddings_contextual)

# %%
reviews_df['review_vector'] = reviews_df['lemma_embeddings'].apply(review_vector)

# %%
reviews_df.head()
# Out:
#                 review_id             business_id  stars                                         categories                date                                               text                                             lemmas  num_lemmas  month  review_length  avg_word_length                                       lemma_tokens                                   lemma_embeddings                                      review_vector
# 0  mG1FavLfA5j2L83sCZ3rFg  drTZrkbpSoJgwKETlFbc3w    1.0  Shopping, Musical Instrument Services, Musical... 2022-01-01 15:47:07  I bought a Fender 1966 Telecaster that the sal...  buy fender telecaster salesperson tell origina...          50      1            641              5.0  [buy, fender, telecaster, salesperson, tell, o...  {'buy': [tensor(-0.3502), tensor(-0.3202), ten...  [tensor(-0.1198), tensor(-0.0008), tensor(0.11...
# 1  WMpnr1XBJ5U38rfSdErhJQ  jyxHti29yWdYR00Itt1A2w    5.0                         Restaurants, Mediterranean 2022-01-02 03:49:01  This is our go to for take out when I visit my...  visit son restaurant desert home food authenti...          14      1            208              4.0  [visit, son, restaurant, desert, home, food, a...  {'visit': [tensor(0.2472), tensor(-0.1876), te...  [tensor(-0.0457), tensor(-0.0798), tensor(0.29...
# 2  99EMi0lRhdmylbG0soaf9w  Jo4ei-c-5H53IxZxAVf1jQ    5.0  Hair Salons, Men's Hair Salons, Barbers, Beaut... 2022-01-03 03:17:03  Danielle did a great job!  She listened and cu...  danielle great job listen cut hair way request...          24      1            278              4.0  [danielle, great, job, listen, cut, hair, way,...  {'danielle': [tensor(0.2697), tensor(-0.6797),...  [tensor(-0.1339), tensor(-0.2695), tensor(0.25...
# 3  Qs4z8e7hCoU9EzRKD9rGPQ  YT5CjacTllBtvMaMJS3IbA    1.0  Hotels & Travel, Hotels, Venues & Event Spaces... 2022-01-05 15:55:59  We saw a lot of roaches in the bathroom when w...  see lot roach bathroom wake bed large dark sta...          38      1            514              4.0  [see, lot, roach, bathroom, wake, bed, large, ...  {'see': [tensor(0.1202), tensor(-0.0037), tens...  [tensor(0.0055), tensor(0.0707), tensor(0.2249...
# 4  SXZ2Nw9UGAgPlXJsju9fFA  9MHe5jAym2d8VhT_NbCRyw    2.0                         Restaurants, Chinese, Thai 2022-01-06 03:59:21  We  Ordered pork fried rice and beef chow mei ...  order pork fry rice beef chow mei fun teriyaki...          16      1            148              5.0  [order, pork, fry, rice, beef, chow, mei, fun,...  {'order': [tensor(-0.5591), tensor(-0.3076), t...  [tensor(-0.0639), tensor(-0.0194), tensor(0.13...

# %%
from sentence_transformers import util

pd.set_option('display.max_colwidth', None)

# Compute pairwise cosine similarity
cosine_sim = util.cos_sim(
    torch.stack(reviews_df['review_vector'].tolist()),
    torch.stack(reviews_df['review_vector'].tolist())
)

# Example: Find reviews most similar to review[0]
similarities = cosine_sim[0]
top_idx = torch.topk(similarities, 5).indices
print("Most similar reviews to review 0:")
print(reviews_df.iloc[top_idx]['text'])
# Out:
# Most similar reviews to review 0:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I bought a Fender 1966 Telecaster that the salesperson told me was "all original".  When I got home I noticed a 3-way switch in the guitar case pocket. I called the salesperson and was told a new switch had been installed, which means that the instrument is NOT all original.  I asked my salesperson to talk with the owner and got no response.  I wrote a letter to the owner expressing my concern about misrepresentation and asked to discuss.  No one ever r ...
# 21603                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          In August I found a vehicle on Ebay that was being auctioned by Mirabella Motors. I placed a bid however the auction never met its reserve so the auction ended without a winner.\n\nWhen I saw they added the vehicle back for sale I got in touch with Tony Mirabella. He let me know he lowered the reserve and that If I wanted the vehicle I could send him a deposit and he would close the auction.\n\nBefore I sent the deposit I expressed some concern since I was unable to go and see the vehicle in person. On the phone Tony went out of his way to assure me he was a "reputable dealer" and that I would be "happy with the vehicle". I thought it prudent to send him a quick email which spelled out that if the vehicle didn't match the description that I would receive my deposit back within 30 days.\n\nAfter sending the deposit I immediately scheduled an independent inspector to go and check out the vehicle. Tony passed me off to another employee to get the inspection scheduled and after a couple of weeks they were able to retrieve the vehicle from another auction and make it available for inspection.\n\nThe inspector was to review paint, interior, and quality of maintenance. They also perform a test drive however for some reason that day the vehicle wasn't able to be driven. In any case the inspection report came back with photos and a narrative that indicated poor color match and door jam and fender mis alignment. An airbox that was stuffed with leaves and greasy hand prints on the interior door (Light Gray Interior).\n\nWhen I got back in touch with Tony to let him know I would like my deposit back he initially wasn't available. Then after several weeks he was "slammed since getting home" and that he would "get to it next week".\n\nAfter a week or so I followed up again and he asked me the address where to send the refund.After another week or so I followed up again and he asked for a copy of the inspection report.\n\nAfter another week or so and on regular intervals I've followed up with him and their office through email, text, and phone calls. I have been ducked and dodged with no answers except a request to not leave a negative review and "I'll follow up with Tony".\n\nMy deposit was on the magnitude of thousands of dollars which as of now it seems I'll have to file a small claims suit in order to recoup. Since i'm out of state I'll have to pay an attorney to stand on my behalf.\n\ ...
# 13858    I had an ok experience at Wesley Chapel Toyota. I called on a Saturday, left a message, and Melanie called me back later that day. I was calling to inquire about the 2021 Venza they had online. Melanie had to check to make sure they had it. So, she texted me back stating they did have it and they were getting another one in about 6 days. The one they had was the LE and the one coming in was a Limited. It was late in the day and I stated I would probably drop by the next day (Sunday). I called in the morning when they opened and asked for Melanie and someone took a message and said she would call me back soon as she was arriving in about 10 minutes. I waited an hour and received no call back, so, I decided to go in (about a 30 minute drive) to look at it in person. I arrived and was met at the door by Tino. He took my name and phone number and found me in their system. He said he would let Melanie know I was there since she was helping me and to have a seat. He came back 5 minutes later and stated she was something (I didn't catch the title) and I'm guessing not an actual sales associate, but rather someone who contacts customers, etc. She told him the vehicle was sold. It's possible the LE Venza they had was sold, but someone could have saved me the drive and called me back to tell me. He then looked and said that he saw it on the showroom floor. He went back and asked her again. He then came back and stated she told him again that it was sold. He said let me look into it and later came back with a key and had asked someone else whom I guess informed him the vehicle wasn't actually sold. How come there is such confusion as to if a vehicle is actually sold or not? Wow! The level of incompetence here is quite unfathomable. You can imagine through this whole ordeal I was quite upset. Tino sat down and was trying to spin it in a way so that he wouldn't be blamed and I didn't blame him. He came into a situation where the others who should have been on top of this... wasn't. He tried making excuses as to there was a shortage of vehicles and that he understood it is a frustrating situation for him being the salesman and for the person purchasing the vehicle. I understood, but it didn't really make up for everything. From here came the multi hour process that one becomes accustomed to when purchasing a new vehicle. We finally agreed on a price and I wanted to take advantage of the current promotions of 0 down and 0% interest. He said, yes that it would be 0 down and 0% interest. Test drove the vehicle and was pleased with it. Finally got to the time to do the financing and met with Aiman. He was easy to deal with and was a pleasant experience. Of course, he went through the whole thing of trying to sell me gap insurance and additional options. I didn't want to pay anymore as I was already a bit over what I wanted to pay when speaking with Tino. We finally agreed on coverage that didn't cost much more and would last for many years to come. When I asked about the 0% he said that no, he couldn't offer it as it wasn't available for the Venza. I asked why Tino said it would be and he said he didn't know and would have to ask him about it later. At this point, I was at the dealership for hours and didn't feel like walking out after all this. Just another bait and switch that I've come to expect from a car dealership. I finished up signing and met Tino outside where he pulled the Venza up to the car I traded in so I could remove my things from the vehicle. I got my things and drove home. The car performed well and has since for the few days I've had it. I didn't see this before when I was at the dealership, but I noticed a small dent in the liftgate when I got home and inspected it closely. The Venza is black so it didn't really stand out, but at a certain angle is visible. Awesome right? I guess if that is the worst the vehicle has wrong with it then whatever. All in all, the experience was just ok. I'm definitely glad to be done w ...
# 16577                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       One star is to generous for this place, I have bought many Ford vehicles personally and through my company new and used for 30yrs from dealerships all across this province and I have never had a worse experience than this place. I bought a 2014 Ford Edge for my daughter just before Christmas that they had advertised on Kijiji. The vehicle looked great with the pics that were on Kijiji and I was assured by the salesman that is was, so taking their word, thinking it was a reputable dealership and trusting them I transferred the money. When I went to pic up the car on the 21 of Dec it was not as advertised, the first thing I noticed was a tear in the drivers seat (that was not on any pic advertised).  I ended up agreeing to pay for 1/2 of the repair whenever that happens. Then I notice window did not pass inspection, neither did the suspension, next was the SYNC radio the touch screen did not work. How I wish I had noticed some of these reviews before I had transferred the money! I have been calling and texting pretty much everyday since I bought the car to see if they were going to stand behind it, all I ask for is some communication and and an email ensuring me that they are going to stand behind the repairs, after 2 weeks l finally got a hold of the salesman that sold me this thing, (thanks to the most polite receptionist on the planet) and he said that he would get hold of his manager.  Yeah nothing, no response, no apology no nothing, zero communication. This is by for the most unprofessional place I have ever came across, so frustrating, not to mention my dau ...
# 24329                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Trail Appliances on 149 st. Edmonton carries a wide and varied assortment of great product. Unfortunately, their customer service is near atrocious.\n\nWe built our house in 2002 and our builder gave us incentives to shop at Trail. We bought from there and were happy with our appliances, but noted at that time how unhelpful the sales staff were.\n\nProbably about 5 years ago we needed a new dishwasher and went back. It was remarkable how, again, we liked the product but the salesmanship was very subpar.\n\nWe very recently went back to replace most of our appliances and found the same thing again.\n\nWhy would we keep going back you ask? We're quite happy with the appliances! Unfortunately, the customer service is terrible.\n\nEVERY time we've entered the store we've never received a greeting. The Receptionists are too busy talking to each other (every time!), and the "Salespeople" are too busy behind their desks behind the counter (doing what?) to bother.\n\nWe walk the store, walk by multiple "salespeople" without a glance or a greeting, and then have to interrupt them at the counter to get a salesman to help sell us something.\n\nThe last time we were in we got the same salesperson, "Magic", as we had the last time. We again had to pry him off his phone, he gave us incorrect information about what we were buying, and as soon as we hit the counter to pay he was back at his desk. He never thanked us for our business, offered any tips about the appliances our even said goodbye.\n\nTo note, this seems to be a store leadership problem. The "Manager" of the store operates in the same fashion and so seemingly his employees have learned what's acceptabl ...
# Name: text, dtype: object

# %%
from collections import defaultdict

# Gather all occurrences of each word across all reviews
word_contexts = defaultdict(list)

for emb_dict in reviews_df['lemma_embeddings']:
    for word, vec in emb_dict.items():
        word_contexts[word].append(vec.cpu())  # keep as tensor

# %%
from sentence_transformers import util
import torch
import numpy as np

def contextual_variation(vectors):
    """Compute average cosine distance between all pairs of a word's embeddings."""
    if len(vectors) < 2:
        return 0.0
    sims = []
    for i in range(len(vectors)):
        for j in range(i+1, len(vectors)):
            sims.append(util.cos_sim(vectors[i], vectors[j]).item())
    return 1 - np.mean(sims)  # 1 - avg(similarity) = contextual variance

# %%
from sentence_transformers import util
import torch

# --- 1️⃣ Helper: fast contextual variation ---
def contextual_variation_fast(vectors):
    """
    Compute average pairwise cosine distance using vectorized ops.
    """
    if len(vectors) < 2:
        return 0.0
    X = torch.stack(vectors)
    sims = util.cos_sim(X, X)
    mask = ~torch.eye(len(X), dtype=bool)
    mean_sim = sims[mask].mean().item()
    return 1 - mean_sim  # higher = more varied meaning

# --- 2️⃣ Select 3 sample words that appear in multiple contexts ---
sample_words = [w for w, vecs in word_contexts.items() if len(vecs) >= 5][:3]

print(f"Analyzing {len(sample_words)} words:", sample_words)

# --- 3️⃣ Compute contextual variation only for those words ---
word_variation = {
    word: contextual_variation_fast(vecs)
    for word, vecs in {w: word_contexts[w] for w in sample_words}.items()
}

# --- 4️⃣ Display results ---
for word, score in word_variation.items():
    print(f"{word:15s} → contextual variation: {score:.3f}")
# Out:
# Analyzing 3 words: ['buy', 'fender', 'salesperson']
# buy             → contextual variation: 0.000
# fender          → contextual variation: 0.000
# salesperson     → contextual variation: 0.000

# %% [markdown]
# ### DistilBERT

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load DistilBERT (lightweight, contextual model)
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
model = AutoModel.from_pretrained("distilbert-base-uncased")

# Ensure it runs on CPU
device = torch.device("cpu")
model.to(device)
model.eval()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# DistilBertModel(
#   (embeddings): Embeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Transformer(
#     (layer): ModuleList(
#       (0-5): 6 x TransformerBlock(
#         (attention): DistilBertSdpaAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           (activation): GELUActivation()
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
def get_contextual_word_embedding(sentence, target_word):
    """
    Get the contextual embedding of a specific word within a sentence.
    Returns the mean embedding of all sub-tokens that match the target word.
    """
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    token_embeddings = outputs.last_hidden_state[0]  # [seq_len, 768]
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

    # Collect embeddings for tokens matching the word
    word_embs = [token_embeddings[i] for i, tok in enumerate(tokens) if target_word in tok]
    
    if len(word_embs) == 0:
        return None
    
    return torch.stack(word_embs).mean(dim=0)  # Average sub-token vectors

# %%
target_words = ["buy", "fender", "salesperson"]
word_contexts = {w: [] for w in target_words}

for text in reviews_df["lemmas"].head(50):  # test on 50 reviews for speed
    for word in target_words:
        emb = get_contextual_word_embedding(text, word)
        if emb is not None:
            word_contexts[word].append(emb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 6
#       4 for idx, text in enumerate(reviews_df["lemmas"]):
#       5     tokens = text.split()
# ----> 6     embeddings = model.encode(tokens, convert_to_tensor=True)
#       7     for token, emb in zip(tokens, embeddings):
#       8         token = token.lower()
#
# File ~/venvs/python3/lib/python3.10/site-packages/torch/nn/modules/module.py:1964, in Module.__getattr__(self, name)
#    1962     if name in modules:
#    1963         return modules[name]
# -> 1964 raise AttributeError(
#    1965     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1966 )
#
# AttributeError: 'DistilBertModel' object has no attribute 'encode'

# %%
from torch.nn.functional import cosine_similarity

def contextual_variation(embeddings):
    if len(embeddings) < 2:
        return 0.0
    mean_vec = torch.stack(embeddings).mean(dim=0)
    sims = [cosine_similarity(e.unsqueeze(0), mean_vec.unsqueeze(0)).item() for e in embeddings]
    return 1 - sum(sims)/len(sims)  # Higher = more varied meaning

# %%
for word, vecs in word_contexts.items():
    if len(vecs) >= 3:
        var = contextual_variation(vecs)
        print(f"{word:15s} → contextual variation: {var:.3f} ({len(vecs)} samples)")
# Out:
# buy             → contextual variation: 0.103 (4 samples)

# %%
target_word = "buy"

buy_reviews = reviews_df[reviews_df["lemmas"].str.contains(rf"\b{target_word}\b", case=False, regex=True)]

for i, review in enumerate(buy_reviews["lemmas"].tolist()):
    print(f"\n[{i}] {review}")
# Out:
# [0] service: 3
# food quality: 5
# drink quality: 5
# order time: 5
# aesthetics: 5
# noise level: 5
# menu selection: 3
#
# overall experience: 4.4
#
# After visiting New Orleans for Christmas we made this one our must visits after reading all the wine reviews in the town. They have a very large outdoor dining/drinking area with live music.
#
# If you've never been then it's quite simple. You walk into a, what seems like, a small liquor store. It technically is but you buy the bottle, and take it out back to drink, and listen to live music. They have a very extensive selection of wine. I would also recommend ordering a cheese board. We didn't, and we regretted it after seeing everyone else order it.
#
# I gave this place a 3 in service. The employees were nice but it's a very limited interaction. It's basically self serve. An employee at the register when you buy the wine, and after that you never see anyone. You go out back. You Order your food from your phone. The cook brings it out, and then you never see anyone else. They have trays out so that you can clean up after yourself, and all the utensils/glasses are stacked outside so that you can get what you need. This place is more of a social hang out spot, and not service centric.
#
# If you're hungry then be fore warned that their food menu is very limited. We ordered olives and meatballs. Both were amazing but wasn't very filling. Definitely order the cheese board if you're looking to fill your belly.
#
# Overall, we absolutely loved this place. Wasn't what we were expecting, but we had a blast, and loved the music. Such a beautiful spot with an amazing new world Argentinian rose! If you're in New Orleans, please, don't miss out on this hidden gem.
#
# [1] Imprint has some of the most unique beers I've ever had! Their schmoojie line is to die for - we got a flight of 8 different shmoojies and ended up buying two 4-packs and the Christmas advent calendar. They are literally beer smoothies - so unique and tasty. The white chocolate raspberry schmoojie and the passionfruit strawberry and something else schmoojie were HITS. The dark chocolate one was also to die for! These are small batch so in a couple months or a year you might not see the same flavors around, but it's one of the fun parts of trying things here (and most convincing part of wanting to buy everything now).
#
# The Christmas advent calendar was super fun and exciting opening a new flavor each day. Lots of both hits and misses but overall a really fun experience! Will definitely come back in the next years to buy these again for the holiday season.
#
# One thing to keep in mind is they need to be kept in the fridge due to the lactose in the smoothie mix - I was told if they are left in the heat too long, they could explode!
#
# Highly recommend a stop by this place to check out the schmoojies!!
#
# [2] If I could give 0 stars I would. Super unprofessional, unprepared, and rude employees. I showed up to see dresses and they turned me away and made me set up an appointment for 2 days later. When I went in for my scheduled appointment, they said they were not able to help me because they had employees out for the day. They didn't even bother to tell me before hand. I noticed there were two women in there; neither of them doing anything but somehow unwilling or unable to help us. They had zero urgency or desire to take care of a potential customer. I was ready to buy a $2000 dress for my daughter. They obviously don't need the business or customers.
#
# To top it all off they have dresses on display that they said the couldn't order in any other sizes. La Casa Puebla was able to order it with no problem and the owner is amazing to work with.
#
# Don't waste your time with this place.
#
# --------
#
# Si pudiera dar 0 estrellas lo haría. Empleados súper poco profesionales, sin preparación y groseros. Aparecí para ver vestidos y me rechazaron y me hicieron programar una cita para 2 días después. Cuando fui a mi cita programada, dijeron que no podían ayudarme porque tenían empleados fuera ese día. Ni siquiera se molestaron en decírmelo de antemano. Noté que había dos mujeres allí; ninguna de ellas haciendo nada, pero de alguna manera no quisieron ayudarnos. No tenían ninguna urgencia o deseo de atender a un cliente potencial. yo estaba lista para comprar un vestido de $2000 para mi hija. Obviamente no necesitan el negocio o los clientes.
#
# Para colmo, tienen vestidos en exhibición que dijeron que no podían pedir en ningún otro tamaño. La Casa Puebla pudo ordenarlo sin problemas y es increíble trabajar con la dueña.
#
# No pierdas tu tiempo con este lugar.
#
# [3] Looking for a quick and easy breakfast, we decided to go on a walk down Magazine st to see what was open and available. We were glad to find this shop had coffee, savory and sweet items for food so we stopped to try it out;
#
# Everything was really good, and it wasn't crowded on a Saturday. It's a modern rustic little cafe/restaurant with some gear you can buy, and they had quality donuts and the taco was very tasty.
#
# Definitely would go again and try another donut, or two.
#
# [4] We came to this famous "old stagecoach stop turned eatery" on a cold winter day but the vibe here was super warm!   But if the vibe along isn't enough to warm your heart, the ginormous Tri-tip sandwich will certainly warm your stomach!
#
# The meat was done to perfection and the bun was soft... and they give you so much that the two halves of the bun hardly close!
#
# If you buy the $13 sandwich, you'd have to eat out in open tables. There's a restaurant but hard to get into.
#
# The ambiance is rustic, casual and relaxing. Parking can be difficult as this famous joint is super popular!
# CHECK THEIR HOURS before you come (they are not open every day like other restaurants) so you don't end up driving the distance and get disappointed. Lastly, my guess is this place is more enjoyable in the summertime as the shady tree-lines areas can be cold in the winter.
#
# [5] This company is utterly awful.  The entire purpose is to deliver water.  Customers rely on that water delivery and pay for it to be consistent.  Every single time I am scheduled for a delivery, it is postponed.  At first it was a day or two.  Then is started to get longer.  My most recent order has been postponed for two weeks.  If I have to go buy water and schlep it home, why do I have a water cooler?
#
# They are constantly reaching out to you to either raise prices or postpone a scheduled delivery.  The website does not even allow you to cancel, you have to send an email to customer service.  I truly don't understand how this company is still in business.
#
# [6] Best of all the voodoo shops in New Orleans! I had been here 12 years ago and was happy to see it has not changed.   I love to come here to look at the Haitian beaded flags as well as all their other authentic items and shrines. You can really feel the energy here.
# I was looking to buy gifts for my (voodoo) dolls and though it wouldn't be an expensive purchase, the woman working tried to be very helpful.  It was appreciated.  It isn't 'all about the money' as is the case with the two other nearby shops.
# Had I planned better, I would have done a tarot reading, but they were fully booked. Next trip!
# I ended up buying two tea-lite candles for "prosperity" as gifts for my dolls.  I know many do not believe.  Yesterday, a week after my purchase and return home, I received an email informing me of a $540 check being sent - from an auction I had consigned a small item to a year ago!  I had completely forgotten about it!
# Great place to visit!
#
# [7] So I been saving up my money all pandemic and I needed to buy a car. I came across Tim Green outside of work and he invited me to come in and check out his line up of car on the lot. I didn't see anything so I was patient and he did he's homework. A couple months later he calls me up and tells me he has the car for me and here I am with my brand new car and I couldn't be any happier. The staff was so helpful and new I wanted the best value for my buck. Super happy, no complaints
#
# [8] Honestly, I give this place 2 stars.  Most of the staff is very nice and helpful; however they definitely know where to grab your wallet.  I purchased my bridesmaid gown here for a friend's wedding for under $125.  That's a great deal, right?  Hold up, where they get you is in the alterations.  They should be ashamed of themselves.  I paid $165 for alterations on a $125 dress.  I didn't need that much done, hemming, of course, tighten up the shoulders, which wasn't really done and take a very small amount in at the back of the bodice.  Everyone else in the bridal party paid under $100 for their alterations and had the same things done to their dresses. Not to mention the fiasco when I tried to cancel my fitting appt because I was positive for covid.  They couldn't find my name in the system, then had a hard time finding me when I came in to pick up my dress.   I will never buy from this company again.
#
# [9] It's a cool idea. To go buy a bottle of wine and then go sit and drink it. I just wasn't into wine the night we went.
#
# [10] don't buy wipers from Lube city.
# one broke off at the tab after 6 months, the other broke off this week.
# I replaced the first one, but after the second one broke off I felt a replacement or a discount on a replacement was in order.
# was told they don't warranty their parts.
# this after getting service work done there for many years.
#
# [11] Would give zero stars if I could.
# Was genuinely perturbed by the amount of racist imagery throughout the shop as I walked around, including but not limited racist figurines of African-Americans and East Asian individuals. These items perpetrate racist stereotypes unnecessary ever but especially in the 21st century.
# But the worst part was when I turned the corner into their war section. This section was covered with items from WW2, both Germany and Japan, and Vietnam. There were clear Nazi items as well as a selection of knives that were displayed as having been used in these wars. They were also selling someone's Bronze Medal which seems incredibly insensitive to the person who earned it. Some of the Nazi items were only on display, such as a Nazi women's uniform, but many others were available to be sold. There were no warnings when you entered the section but instead there were small signs on the most offensive cases saying they did not agree with some of the items displayed and that they were items taken from the nation's enemies to be sold to collectors.
# As a Jewish person, seeing Nazi items without warning is incredibly offensive, if the owners of the store want to respect and honor the veterans of the past, they should donate these items to places where they will be displayed as history rather than items to buy and sell. A gas mask used in a war is not a collectors item, it was most likely used to kill a human being as were the war-era knives.
# On the topic of the employees, they did not really pay attention to anyone who did not seem like they were tourists and seemed to only speech to people who were clearly from out of town and willing to spend quite a bit of money. I will most definitely not be returning and will be recommending to other local antique-lovers that they avoid this place.
#
# [12] Best dealer across country for Jeep Wrangler service and purchase by far. I travel all the way from NC to buy my cars from Tom and his team. Nothing compares.
#
# [13] Best sushi in central bucks area. Never a bad meal here. I've ordered almost all the rolls at some point or another. You wouldn't think much of it by walking buy since it's in a strip mall. However the food is phenomenal. I almost don't want to review it because it will make it even more busier than it is. Be prepared to wait longer than the estimated time they give you on a weekend night. Definitely worth the long wait.
#
# [14] Terrible customer service. Purchased a gun on Monday. The value of the gun was 305.00. I got home and realized I wanted a better one. I called there on Friday morning and spoke to a lady. She said I would be able to exchange it.
# When we went to the store, there was a gentleman that stated we had to have it evaluated and it marked as used.
#
# When we went to customer service, they said we would only get 75.00 back. It was never shot & in the original box.
# When we purchased it , the box was already open.
#
# So this gun was probably returned by someone else.
# This a disgusting way to do business.
# Do not buy ammunition there, Ammoseek & outdoor.com have better prices.
#
# [15] I would not recommend pit bull for body piercing. I haven't gotten a tattoo from here so I cannot comment on that aspect. I went to get my second lobe and daith done at pitbull about a year and a half ago and after a few weeks I removed the daith piercing as it was extremely uncomfortable. As far as my second lobe piercing I followed all the after care I was given and one day it had swelled up so much that I thought the back of the earring was covered in scar tissue and how to get an X-ray taken of my ear. Thankfully it had been pushed off from the swelling, however I removed the jewelry that it was originally pierced with and waited for it to heal. After awhile it was healed and I contacted another studio about re piercing my lobe. When I went they commented on the poor placement of the original piercing and the angle that it was done at. I would not recommend pitbull for piercing to anyone, the buy one get one half off deals they have are supper cheap but are terribly done, I wasn't given a choice in what jewelry I wanted, and my friend who had her double helix done there had to have them both removed as well for how poorly they were done. I would honestly just save up some extra cash and go to atomic zombie or showdown. Far better experience and piercers at both of those studios and well worth the money.
#
# [16] No one likes working out, but if you're going to do it - this is the way to go.  Get your cardio, strength and flexibility all in one nonstop hour.
#
# This particular studio is clean, well organized, and the instructors I've had know how to both push you and motivate you.
#
# They knew everyone in the room by name. They also handed out arm bands if you were ok with the instructor physically correcting your form/touching exactly where the workout should be making your muscles cry. (It's nice to be asked whether or not you'd like to be touched.)
#
# Extra bonus points for this studio: we didn't use the little slider discs. I hate those things with a capital HATE. (I'm sure we will one of these days though.) Also this studio doesn't push you to buy its products. Classes are done barefoot as opposed to using pricey branded grippy socks.
#
# Barre in general works on balance, flexibility and strength. Just when you get to the point you think your abs or glutes or arms can't take another rep, you're changing exercises. And there's super peppy music behind it all. Usually there's a Groupon for classes - so if you're shy about it or not sure, try it out before making a big monthly commitment.
#
# It isn't cheap, but it IS worth it. Barre gets results. Fast.
#
# You probably WON'T get every move right the first time and all the muscles you worked on WILL hurt like crazy the next day, but go back! Eventually your toned up tush, flatter belly, and fabulous arms will be able to make it through the entire workout.
#
# [17] Amazing service - would buy another Toyota just so that we can keep going to these guys. Probably the best mechanics I've ever dealt with.
#
# [18] This place was everything I envisioned when getting Nashville food and having a good experience. Let me tell you, the chicken sandwich I got was easily, without question, one of the best things I've ever eaten in my life. Me and my girlfriend legit started laughing because we were shocked how amazing it was.  The ambiance is amazing too and there's plentiful amounts of seating. We showed up to a band playing too and honestly it was the first time I was actually influenced to buy the bands music since they were amazing. Servers were funny and made the time even better. How could I almost forget, the beer was absolutely phenomenal. The ONLY thing I didn't love was the location which is like at a weird underpass area but honestly, with all the upsides, does that really matter?
#
# [19] If I could Give this experience zero stars I would. First of all there's absolutely no parking it was impossible to figure it out  and took us over 30 minutes. no ticket sale after 2 PM and there was actually a line to buy tickets at the event but the line was a mile long. I finally got inside and there were only 2-3 barbeque style food places and the lines for the food were INSANE. Not to mention Karens running around wild here. We finally settled on a fruity pebble donut from a donut food truck. That donut was the only morsel keeping me alive for the past 5 hours fighting off karens left and right. Wouldnt recomend this event unless ur a karen
#
# [20] DO NOT BUY A MATTRESS HERE!! This guy should be shut down.   He did the old bait and switch.   I picked out the mattress I wanted and was shipped something completely different.  I could tell the difference immediately when I sat on the mattress.  Even though it had the same name and same design. I took a picture of the label  on the mattress  which has the information of what it is made of and layering/padding information.  Then went back into the store to confront Peter.  Low and behold when I compared the label of the mattress I received to the label of the store model which I really loved  it was NOT the same bed not even made out of the same material.   When I confronted Peter of this he responded.  Ohhh. Well the store model is a few years old and the manufacturer company has just sold to a new owner.  I'm not sure what they make the new models of.  But this is the same bed.    He new dam well and I paid 3,000 for a mattress that is worth $500.  Needless to say I'm writing this review a year later and the mattress is sagging and my wife and I are going mattress shopping again only a year later minus $3000.
#
# Peter is crook and somebody needs to shut this guy down.  I can't believe in our small community he has not been run out of town.   Worst sales experience of my life too.  He just talked about himself and how he was from the hood in Compton and had to grow up fast and fight his way out of the hood and how all these celebrities buys mattresses from him. Who cares you tool.  He's totally full of S?!$&. You can't even get a word in edgewise wise with this guy to ask a question.  Loser.
#
# [21] Delicious place that makes you wish you had two stomachs so you can try everything! The bagels are soft and the toppings generous. They do only season one side of that matters to you. We got a half dozen for our friends and they confirmed this place was the place to go. Never had a lox bagel with sprouts and at this place it is a standard--- I'm convinced I've been missing out this whole time. Coffees was pretty good according to my date; I didn't get to try the espresso because they put it inside my hot cocoa (an honest mistake I suppose). I didn't try the donuts but they stared at me looking delicious the whole time. I absolutely loved that you could buy the everything seasoning they make fresh. Team there was friendly and fulfilled the orders quickly, even during the rush. We got there *just* before the line started going out the door. Kind of a random location so my best advice is to take your bagels to the park and enjoy them there or sit at the window and enjoy quality people watching! Bon appetit.
#
# [22] Back in July of 2021 (the 17th I believe) I went into Clarkson Eye Care (South) at Hwy K and N in O'Fallon, Mo. I needed to order a pair of everyday glasses with my new prescription and I also wanted to order a new pair of sunglasses. I have worn glasses since I was 16 and I am currently 42 years old, so I am no amateur at this process. I had already picked out a pair of sunglass frames at Lens Crafters but wanted to purchase them along with my everyday pair at Clarkson Eye Care near my home. When I went into Clarkson I picked out a pair of everyday frames and sat down with a tech to set up my order. At that time she told me they do not carry the pair of sunglass frames I wanted and that I would have to go purchase them from Lens Crafters and bring them in to them to send off to their lab for the prescription lenses. We went ahead and sent the everyday pair into the lab since those were most important and I was going to buy the sunglasses and bring them in to Clarkson once I got them to send into the lab. I found the frames on Amazon and ordered them. I got the frames in and took them into Clarkson that following week. I had went in to order all of these at that moment because I had a trip coming up in August and knew that should be enough time to get everything back. I waited and waited and my trip came and went and I did not have either of my glasses back so I was still wearing three year old glasses which takes me back one year. A year prior to this, I ordered a pair of glasses from the Clarkson Eye location in Lake St Louis, Mo. I got them in and started to wear them. This was the beginning of COVID and masks, and the new pair of glasses hurt my ears so bad that I could not wear them. I went in several times, over a three month prior to have them adjusted, each time the tech telling me "it just takes time to get used to them.". Me thinking maybe she was right, maybe it had to do with the masks, and that I would give them more time. I was never able to wear them and by the time I figured this out Clarkson told me I was out of the grace period to exchange them and I never wore them.
# So back to this time around. Around Aug 4th I did get a call from Clarkson informing me that both pairs of glasses were in and I could come to pick them up. Upon arrival at the store I was told to have a seat and that the tech would be with me in a moment. I sat and waited 20 minutes until asking what was taking so long. At this point one of the ladies came out and told me that the lab had sent my sunglasses back with no prescription lenses. She told me she would send them back to the lab, rush order (since I had my trip coming up Aug 13th) and that she personally would follow the order and make sure to inform me weekly with an update, never got one call from her. I asked if I could at least get my everyday glasses and then had to wait another 10 mins. When the tech came out with my everyday pair, I put them on and immediately could not see right out of them (remember I have been wearing glasses for 25 years). I informed the tech and AGAIN was told, "it takes about two weeks for your eyes to adjust." So I left with my glasses and gave it two weeks until I could no longer take it. I went back in to the store (after my trip) and this time asked for the manager. We sat down and she looked at my lenses and right away told me the tech had ordered the wrong lenses (I have a really bad stigmatism) and she would need to send them back to the lab. Now, at this time, I still had not gotten my sunglasses. The office manager told me, when I asked about the sunglasses, that they should be in that following Monday and asked me if I wanted her to send them back because they would also have the wrong lenses in them. I told her I wanted to come up and see them when they got them in and we could talk about sending them back at that point. The following week she called me and told me she took it upon herself to just send the sunglasses back because she knew I would not like the lenses. So here we were, over a month later and I had not laid my eyes on my sunglasses and still did not have the correct everyday glasses yet. I waited another couple weeks and called the store to ask about the sunglasses. I was told they would have to call the lab and find out the status and would call me back by the end of business day. The following day I had not heard back from them so I called again. Again, I got the run around and told there was some confusion with the status and they needed to call the lab again. I told the office manager I would give her until 4 pm to hear back or I would be calling her. 3:30 came around and I called the store. I was told by a physician, that came on the phone when I got really upset, that the office manager had gone home for the day and that to her understanding, the lab had lost my frames somehow and that the office manager would call me the following morning. Around 9:30 the following morning the office manager did call me an
#
# [23] We celebrated a very special day there on Sunday, 1/16. It was a family gathering to acknowledge the one year anniversary of my father passing. We were greeted promptly and sat quickly (we made a reservation in advance). Our waiter (I can not remember his name - younger gentleman with dark hair and dark glasses) was quick to make us laugh and smile. He could sense something was up and was happy to just keep checking on us and cracking jokes. We were so thankful for his kindness that day. The food was excellent and the view can't be beat. They were kind enough to buy my mom a bottle of champagne to acknowledge our day. Thank you, from the very bottom of our hearts, for your kindness and amazing service.
#
# [24] DO NOT BUY THESE COOKIES!!!! All other cookies will taste 'meh' after experiencing these unfortunately perfect treats.
#
# [25] I've been going here for over a year now and I would recommend this place but it's eh
#
# Positives- on occasion I find something really cool, I've found some of my favorite clothing and jewelry at this place. Place is clean and Covid conscious.
#
# Negatives - this place is ridiculously over priced, I mean like some things I understand, but a lot of their pricing is highly debatable. They have some cool shirts that are nice but nothing special that they are charging upwards of 40-50 dollars for. Doesn't sound like a lot but they are def not worth that much. Every time I come back the same overpriced clothing will be there, I don't think they are getting the hint that no one is going to buy that stuff at those prices. I can get over the prices because sometimes their clothing can be worth it. On the other hand their employees can be a little condescending, and their rules are really annoying (tho recently I've had good experiences with their employees and the lady at the jewelry spot was really nice).
#
# Overall, it's worth stopping by, you might find something nice, but it will prob be overpriced.
#
# [26] Great food but worst OJ in town... Menu says "fresh OJ " wtf that's false advertising... I ended up paying $9 after tip and tax for a 99 cent OJ of fake canned/Tropicana/Minute Maid airline or Denny/MCD type OJ. Definitely not fresh nor pressed. C'est se foutre du monde ça. This is the garbage mass produced low cost loaded with artificial sugars OJ you buy in supermarkets. Definitely not Naked or Odwalla where you have pulp. If you want real OJ go to Jeannine's, The Shop or Tre Lune/D'Angelos. Now for good the Mediterranean & Baja scramble & omelette are phenomenal and the diner atmosphere & decoration is great as is service very nice/professional. This feels like a real classic American diner that you get on east coast or in Midwest and always has. Only one in SB now that Essau's is gone. Worker Bee in Carp is phenomenal old school diner too highly recommend. Momma bear would bring me here as a kid after school with my nerd folder organizer box in 80's for chocolate milkshakes at the counter, they had best in town. They still have real milkshakes made with those special classic blenders here so that's great. This is under new ownership from group that owns Brophy. I love all their restaurants but this OJ here has to go. Also my toast was served cold. The food is very good just disgusting OJ, not fresh at all and way overpriced. This was always a true locals spot and still has that vibe so that's a good thing. The new owners did a great job respecting the history of restaurant while also modernizing it. This is one of oldest eateries in town with Joe's. Nostalgia 101.
#
# [27] What a gem of a place in Reno! As a traveler, I needed somewhere that was warm and had enough seating for me to work. This is seriously one of the most aesthetic coffee shops I have ever been to. There is PLENTY of seating (although it fills up quick), baked goods to buy, and an extensive hip coffee and tea menu. They even have merchandise you can rock around town if you fell in love with this place like I did.
#
# Really enjoyed everything this coffee shop had to offer. It's super simple: pay at cashier, wait for name to be called, pick up at the bar. Lots of plugs on the walls as well!
#
# [28] As others have mentioned their listings online are not accurate. I drove over an hour to buy a brand new car outright. 1st they claimed that "that car shouldn't be listed" 2. They said it was sold. 3. After driving around we found the car we were looking for, VIN matched out.
#
# After all of this, they wanted 40 k higher than the price online! I get mark up and dealer fees, but 40k?
#
# The man claimed it was due to "big tires and a lift".
# He was extremely condescending asking me "if I knew what a suspension was?"  The salesman was incredibly uneducated, he didn't know aluminium v steel wheels. He claimed the "new wheels" on the truck were steel, and that stock was alumunium, and that is why there was a mark up. What "steel" wheels are 40k?
# He also argued back and forth over, and I had to tell him to not speak to me so rude. I left, and will never return.
#
# Dont waste your time. They lure you in with low prices online and have extremely rude (and sexist) salesman.
#
# [29] Hello- I am a long time Kroger customer and this is the first time I've written a comment.  Today was XTRA busy due to inclement weather rolling in in the next 24 hours and at 11am all the lines were half way down the isles. They were short handed to say the least! Then I saw a young woman with 2 boys under the age of 5,  with a very full cart of groceries pull her cart over to the side, then sat her boys down on the floor behind an unused Register and jumped on the next open Register and started cashiering and bagging peoples groceries!  I was so overwhelmed with this employees graciousness to step up and help out when it was REALLY needed and APPRECIATED SO MUCH!! And the lady customer behind me asked if she could buy her boys a candy bar or chips to hold them over while they waited patiently for their Mom to finish her good deed for the day! Her name is Tracy and she deserves to be recognized for her for this!! Love my Kroger!!
#
# [30] The sales man told me to buy the bed today and next week on the holiday I can get a credit on the difference , That was a lie .
# There salesforce are liars .do not trust them !!!
#
# [31] This could be your new go to eatery when in Reno Nevada! Visiting from Sacramento California without a clue on where to go for delicious food I found myself walking through Circus Circus, Silver legacy, and then the Eldorado Casino which is now known collectively as " The Row." On a solo mission to eliminate my gastro rumbles I stumbled  upon this super cool looking restaurant/microbrewery in the Eldorado Casino. Curious about what people were waiting thought to myself,"this place must be good if there's is a line, music playing, plus one of the most attractive beer  manucturing apparatuses seen from the outside and within.
#   Questioning the pretty hostes about the wait time I skipped the wait and was able to seat at the bar immediately. Looking though their Happy Hour menu and drink menu. I decided to go with the happy hour special of two 10in pizzas which was buy one get freee. In need of a cold one to wash it all down I went with a tall 22oz Big Dog IPA which was brewed in house. After feeding on my Hawaiian style pie and saving my Combination Pizza pie for later I was  surprised on how well my drink went with my pizza. Perfect match and deal for less then 30 doll hairs, I  could've shared these 2 pies with a friend.
#   In comparison with simular places I've visited in town there's little to no competition i could relate Brew Brothers to. Even with the line reaching around their outside patio from the  entrance , I received my food and drink within 15 minutes after ordering!  If I could give 6 stars    I would because of  the most friendly service I've experienced at any bar/restaurant, the best eye candy ambience and  for the most satisfying Pizza pies you can get in town.
#  So If you're visiting or new to Reno and need a friendly,clean, family style establishment to enjoy . Come and visit BB! You won't be disappointed.
#    Best regards to the crew and management  for creating such an awesome place for everyone of all ages to enjoy.
#   Grazie!
#
# [32] Ordered three pies plus one order of meatballs.  Also requested plates, napkins, silverware, crushed red pepper and grated Parmesan.  Got none of those things which generally wouldn't be that big of deal.  BUT since everything is packed up....my husband had to go to the store and buy items in order for us to eat comfortably.  Dissatisfaction makes me look closer...carnivore pizza didn't include cheese or sauce for that matter, all the way to the edge.  I don't mind spending money AT ALL when the food is good.  Since this isn't the first time pizza has been inconsistent (set aside plate etc issue) think I'm done with Anthony's.  It's just not that good.  Will spend $100+ at another and more deserving pizza restaurant.
#
# [33] I don't know what happened but I went here 3 days ago and I got an oil change for $100, they literally did nothing else. My tires all still needed air, I had to stop at the Wawa right down the road to fill them all right after. Now 3 days later I looked and they didn't fill any of my fluids. I needed to stop and buy anti-freeze and washer fluid and fill them both myself. This is not the first time my tires were not filled after a service. I will never go here again....
#
# [34] New Year, new hair. Or so I hoped...
#
# After a thoroughly lackluster but nauseatingly expensive ($225) 'curly cut' by She Who Will Not Be Named the end of last September, come January 2022 I was dismayed at how frowsy I looked but I was also feeling very distrustful of letting any more curl "experts" get near my head. My choices were to cut it myself (been there, done that), fly back to San Francisco to let Rafiki at Pastel Salon do the deed (not really practical for any number of reasons) or find someone closer to home (Center City). That is how I found myself and my curls at the Andre Richard Salon.
#
# I was early for my appointment with Ava Darling but she greeted me warmly, took my coat, got me draped and seated and chatted briefly about what I was looking for. She was finishing up with another client and gave me a timeline when she would get started with me. Since I always travel with something to read and the salon's atmosphere was calm and relaxed, it was no sacrifice to sit and zone for awhile with the latest New Yorker magazine. There was music playing but it was so unobtrusive (which is always great), it simply added to the 'ah, now let's just slow down and take a breath' ambiance.
#
# Ava is a lovely, courteous, softspoken Scorpio who works very hard at stellar customer satisfaction. She is an excellent listener and best of all (to me), very visual. When I told her what I was looking for in a cut, she immediately got out her phone to show me pictures of what she felt I wanted. She explained that it was important to her that both she and her 'guest' were on the same page and pictures were the best way to assure that. Absolutely! My confidence in the outcome of this cut instantly went to 100%. As she did the dry cut, she explained everything she was doing, answered my questions and asked good questions regarding my likes, dislikes, and lifestyle-as in-how much time and effort did I want to put into a style. It was reassuring to me that I was being treated with so much intentional, individual care and not just getting a cut/style that she wanted to do.
#
# After the dry cut, where I exclaimed that I looked 1,000 times better already as well as 10 years younger, I was shampooed, given 2 separate treatments, one to brighten up my color, the other a deep conditioning. Both were part of the cost of the cut but they made me feel like I had booked a spa day as I relaxed under the dryer. Again, with every product she used, Ava explained what she was putting on my hair, why she was doing it and what the outcome would be. At no time did she push me to buy any product she was using or invest in a particular product line. Ava is not 'just' a DevaCurl stylist. She provides full service, so if you are looking for color, any kind of cut for any kind of hair or anything else that can be done to your tresses, she's the woman for you. She constantly checked in with me throughout the 2 hours I was there and I felt very much seen, heard and cared about.
#
# When blowout/diffuser time came, Ava again took her time to make sure all the lines of the cut were in accord with each other and that I was satisfied with her work. I was astounded at what she had been able to get my hair to do in what seemed to be an effortless way. I asked about the DevaCut 3 month rule for the next appointment, and she said to see how my hair was growing out, what and where I wanted to go next with it (my first thought was curly mohawk) and asured me that it was fine to wait until Spring before I came in again.
#
# In the 7 years that I have been back in Philly, this entire hair affair, from making the appointment and pre-paying online to having Ava help me into my coat as I was preparing to depart, was, without a doubt, the easiest, nicest and most satisfying haircut/salon experience I've enjoyed. I can say with a big grin that I will be most definitely back again!
#
# [35] Arch Apparel is the perfect store for Gifts, Gift Cards, or splurging on yourself. The clothing is high quality with very cool and hip Logo's. The Circle Logo has quickly become a classic STL style. Be proud of our city while supporting a local store owner.
#
# Adult Clothing, Baby Clothing, Hats, Jackets, Hoodies, Housewares, Pet Items all can be found inside the walls of Arch Apparel. This store posts new collections and collaborations in Instagram. Follow them to stay in the loop. I was able to buy many items from t shirts, to hats, to ornaments, to pet gear, and gift cards for holiday gifts this past Christmas Season. The recipients were all very happy and I can report most broke the items in immediately. I had to get several of the Nelly collab items for myself, and I get compliments on them all.
#
# This location of Arch Apparel is in a very high traffic area of Hanley. Look for the White and Black building on the West side of the street.  There are currently two other locations as well. Arch Apparel does a large pickup business, order online for curbside pickup.
#
# [36] Stay away from these people. I wanted a Husqvarna MZ61. Saw one I liked on their website. I called in the middle of a weekday to ask if it was still available. No answer at sales dept, no answer at customer service. So I left messages. No calls back from either. So I did an online inquiry (you know, "contact us"...). No response for days. So I ORDERED an MZ61 from SLE online....when it came to payment screen I had choice of credit card or financing. I chose financing. I actually got an order number and it said "Congratulations on your purchase. You will be receiving a confirmation email shortly". Three days later NOTHING. No email, no phone call....crickets.
#
# FOUR days later someone calls me, "Were you trying to buy an MZ61?"...ummmm, yes, but you aren't making it very easy. "Well you have to click the 'Finance' button on our website". Well it didn't say that. I printed the confirmation page and it says I will get a confirmation email and someone will contact me. "Well that's not the way it works". Soooo....I went elsewhere and bought a John Deere Z540M zero turn. Great buying experience at Ag Pro. These SLE people are boneheads. By the way, I got a canned marketing email yesterday, TEN DAYS LATER, from a "Jerret W" at SLE. He was responding to my very clear question asking if "MZ61 was still available?". He didn't answer the question. Clearly didn't even read or see my original inquiry. Just sent me a canned marketing response. I responded "Hey Jerret, you are a little late to the party brother, I spent $6,000 on a new John Deere four days ago". Unbelievable that I literally clicked a button and spent $5,000 on their website and nothing happened after that. Sad for them really. I was imagining what the experience would have been if I did actually buy it and needed help or repairs later. No thanks....
#
# [37] Very solid customer service here. We had just come from Lucchese. The quality of the boots were very good and the pricing was affordable in comparison. It was really nice though to be invited to sit down at their bar and have a bourbon because it gave me a few minutes to talk to them about their company and how they compare to other companies out there. They gave me their origin story and really turned me onto checking out their boots in the future when I'm ready to buy a pair. Many of my friends swear by this brand and I will definitely buy them soon.
#
# [38] Some of the best Thai food in Philly! I tried this place for restaurant week and had the best experience. The staff was so wonderful and the food was excellent. If you get nothing else, you NEED to try the lemongrass soup. I wish I could buy a bottle of the broth alone. Everything else was spectacular too. I only got a photo of our dessert because the rest was finished pretty quickly. Special shout out to the "baby white elephant" dessert because it was out of this world good.
#
# [39] I pay a gym for good equipment. I can get crappy equipment at an apartment complex. This gym fails. They buy cheap equipment and fail to maintain it. The bikes are worthless unless you want to take their classes. If I wanted you classes, I would have answered your texts the first 50 times.
#
# [40] Went to buy an Audi here with cash in hand, was greeted with a "can you afford this?". Lady inside was as unprofessional as it comes. Save yourself the time from dealing with this miserable woman.
#
# [41] stop!! do not buy from these people!! their policy is straight crap!! you can spend thousands of dollars for a chair, delivery fee. when it doesn't fit the person you are getting it for, they will only swap for another chair. you do not get the difference for getting a lesser expensive chair and they charge you 209.00 again for delivery. lesson learned!!
#
# [42] I was in dire need for new pants for a family dinner. Came to this location to pick up a new pair and was able to buy them with no issues other than the quality and price. However, I was wearing these pants at the dinner and I reached down to tie my shoes. The crotch stream pulled apart and my scrotum came spilling out in front of my whole family
#
# [43] This is one of the Sams Club Best Sams Club in the area because they have items that the one in the Valley does not. I was very unhappy to see that they don't have men's dress pants anymore which is ridiculous as I used to buy the perry Ellis from them and now they don't have them. I recommend the store because the prices are very good competitive what are the stores and have more supplies at this location than most other locations. The people are friendly and will help you find things or if you have problems with your credit card or checking out that there for you!
#
# [44] Went here for a date night with my girl for the first time last night and let me tell you guys this place is awesome! We started off with Guacamole and it was better than your average guac at a Mexican restaurant. We also got margaritas and I got a beer, both great. For dinner I got 3 tacos, Shrimp, Brisket, and Carnitas. All 3 were phenomenal, but the Brisket taco stood out from the rest. I also got a side of Street Corn which was also amazing. If you don't want TexMex style food they have great meat you can buy by the pound or half pound. Their BBQ and Brisket is very flavorful, and I will be going back soon to try the smoked chicken. This place is a bit pricy, but for a date night I don't mind plus the food and drinks was worth the price. Other than the food the inside looks very nice, it walks a fine line of being elegant and "Nashville Hipster". I will definitely be going back and taking friends with me!
#
# [45] We get our knives sharpened here and they brought back a knife someone put in the dishwasher that we were convinced was ruined back to use. Also great spot to buy gifts for someone who loves to cook.
#
# [46] I live about 20 minutes from this place, but this is still my go-to place for BBQ. Well worth the travel.
#
# We get the half-chicken platter, which also comes with two meats, two sides and cornbread. We get the pulled pork and brisket as our meats. They offer plenty of sides too, so there's options for everyone. You get a ton of food with the platter, so it's more than enough for two people.
#
# Their BBQ sauce itself is amazing--sweet but also perfectly tangy. And the good thing is, you can buy bottles of the BBQ sauce! They have a store at their location where they sell locally made goods, and they also sell family meals to-go. Their desserts always look amazing, although I confess I've never tried them.
#
# And I've only gotten takeout, but you can dine in as well.
#
# Overall, love this place and and highly, highly recommend.
#
# [47] Where do I start
# 1) I purchased my new Kona with them and had them install a remote starter and was bamboozled into the "free oil change package as well". FYI I live 2.5 hours out of the city and when I called to enquire about the details about their program, they did tell me that in order to get the free oil changes I would have to agree to all the "recommended" service packages. Service package 2, fyi, is $150. And in addition to the oil change, all they do is grease the hinges of the doors and add a fuel injector cleaner, calling it "injector serving". I can buy the injector cleaner off the shelf at Canadian tire for $10. And who in their right mind would drive 500km to get an oil change, and have to wait 2 hours for it to be completed?
#
# 2) When the first winter hit, I noticed that the remoted starter (2 way) came with two remotes. I used the second remote and it was not a 2 way. I called them on this and they had me book an appointment later for them to order parts and for them to "check it out". When I drove down and checked in, the desk clerk there told me that "That's the way they come. there is nothing we can do about it"  Um so I just drove 500 km round trip for nothing?  A phone call would've be nice to cancel this. I asked this of them and got a shoulder shrug.
#
# 3) Most recently my kona has developed condensation in the DRL. A sealed unit which should not be getting condensation. This is a common issue by researching online. I called them to enquire about this and the desk clerk started to tell me about having to pay $79/hr fee to get it diagnosed. Um what about warranty? When I started to ask about this, she hung up on me.
#
# 3 strikes and you are out!
#
# DO NOT GO THERE FOR SERVICE. I have moved my business to Northstar.  (if I could rate 0 stars  I would)
#
# [48] We tried to do business with Larry Miller Subaru but they apparently did not want to sell us a new car. The sales manager was the only person in the country that actually said that used car prices were down and inventories were up. The offer they made for our trade was ridiculous. We did buy a new vehicle from Twin Falls Subaru and they were fair, honest, and nice.
#
# ...
#
# I thank God that the kids enjoyed themselves after that unnecessary exchange with the face of the company.
#
# [488] Fraud.. Do not buy anything from them.. You will never receive your furniture... Good luck, you have been warned.
#
# [489] Power replaced every window in our house. My wife and I were concerned about how the process would go, having never undertaken anything like this before. We were very surprised and pleased at how relatively smooth the process was. Our crew, led by Alex, could not have been better. They replaced all 31 windows in 2 days, leaving minimal mess behind. The only things that went wrong were 1 window being received broken and the salesperson leaving out one small window in an upstairs water closet. Both items are on order, and Power will be installing them in the next few weeks. Like many other people, our only complaint is the very long sales process - over 4 hours. We typically don't buy from door-to-door salespeople, but this purchase turned out pretty good. The window look great! Another shoutout for the awesome Alex, and his installation crew. They were great!
#
# [490] DO NOT BUY FROM TEAK BROS.  I was SO excited when I saw the boat tables.  I'm picky when it comes to furniture, but these tables were beautiful and came with a repurposed story that I wanted to support!  I'm also exceedingly cheap so dropping a grand on a table is outside my comfort zone and testament to how much I loved this table.
#
# Purchased in early Oct with a late Nov/early Dec delivery date.  Late Nov rolls around and I send a check in email.  Late Nov rolls into Early Dec and I send a follow up email.  I received the same vague, sorry about the delays, email everyone else seemed to have gotten.  I email again Mid Dec hoping to get a firm date, even if it was pushed out a month or two...just give me a solid expectation.  No response.  No response to Instagram messages either.  Called the store and it went straight to a full voicemail.  In reading other reviews it appears the store front itself is shut down.
#
# In reading through other reviews it appears as if there are issues even once the table is delivered...damage on delivery and/or cracking/warping of the table itself.  I've filed a complaint through the BBB and luckily received a refund via PayPal.
#
# [491] My husband and I went in on December 1st to buy a 2022 4Runner. As with most dealers, we had to put down a deposit to hold an incoming car ($2,000) as none were available on the lot. We were given a receipt and told that the car would arrive between December 23rd and 27th. On December 20th, my husband called to get an update on the car. We were told that the car was on the lot, but it just needed to be prepared to go home. We live close to the dealership, so we drove up to take a peek at the car. As we were looking in the windows and getting excited about the new car, my husband gets a call from the dealership saying the person we spoke to earlier was confused and that the car that arrived wasn't ours, it belonged to someone else. He went on to say our car was delayed and he wasn't sure when it would arrive, but there were other options we could look at that were coming in sooner. When we went home, I decided to compare the stock number on our hold deposit receipt to the stock number written on the car we saw on the lot - they were the exact same. When we approached the car salesmen about the car being double sold, he confessed that it had been double sold to us and to another gentlemen. Instead of telling us the truth, he was told by his manager to lie to us and tell us our car was delayed. I was absolutely astounded that management would put their employees in this position. If Lou Fusz would have been honest up front with their error, we would have just bought a different 4Runner from them. After being lied to, I will never buy another vehicle from Lou Fouz. My husband is 30 and I am 28. We were paying cash for the car. Lou Fouz has lost a customer who had many more years of car buying in them. Even in a messed up world, honesty goes a long way. Be aware in this car market when you put down a hold with Lou Fusz!
#
# [492] We went there today for my daughter's prom gown. We were here 5 years ago for another daughter's prom gown. Both experiences were top notch. Although my daughter five years ago did not buy her dress there, they had a huge selection and the sales associates were extremely helpful. Today  with my youngest daughter they did not disappoint. She found a beautiful gown. She as well had many many options. The greeting that we got when we entered made us feel very comfortable, it is not pretentious at all, and the atmosphere is a happy one.Yes it is a small store, yes parking is tight (we parked across the street at Wells Fargo bank, it was a Sunday , So the bank was closed) but the choices are limitless and the prices are on target. Lauren was our sales clerk and she was knowledgeable, professional and had a great understanding of the stock. She learned quickly what my daughter liked and the dress we ended up buying was one that she picked for my daughter. Would highly recommend. We came over the bridge from Jersey.
#
# [493] Amelia's bakery has a lot of fine offerings but the thing that I love the most is their bread. I drive from my home west of Indianapolis to Fletcher Place just to buy their bread. This bread is what I refer to as crusty chewy bread and it's some of the best I've ever enjoyed. Sour Dough based breads that will make your mouth water. I like to toast the bread and then smear it with butter or Cream cheese. If you're lucky enough to go on a Wednesday when they have their bagels try some of those too, the everything bagel is coated with so many wonderful seeds and pieces of garlic and onion. It's the best I've ever eaten. Amelia's has a lot of beautiful pastries too and I'll have to be honest I haven't tried a lot of them. The ones I have tried have been very good. They sell a lot of other specialty meats, vegetables, mustard's, sauerkraut's from locally sourced companies.
#
# If you're looking for one of those special, out-of-the-way places where the people are always friendly and everyone knows your name go to Amelia's! OK I made up the part about everyone knowing your name. I suppose if you go in there enough they would remember you. The staff is always friendly though!
#
# [494] I managed to get a very last minute reservation for last Saturday to celebrate my boyfriend buying his first home! I called a couple of hours before to see if I could buy a bottle of champagne ahead of time to get brought to the table as a surprise and I spoke to Eric. He was so nice and helpful and talked through their options, I ended up picking one and paying over the phone. When we arrived, his wife Christine brought the champagne to the table to excitedly and congratulated him so genuinely. They even placed a card on the table that said congratulations! Christine and the whole staff were so nice and I enjoyed talking to everyone. I wish I remembered our servers name but he was great too. Portion size was great, and everything we ordered tasted amazing. I love the atmosphere and the open kitchen concept. Eric and Christine, thank you SO much for making us feel so welcome and helping us celebrate this huge milestone for my boyfriend. Can't wait to come back!
#
# [495] Wonderful experience for the cruise!  First off, the equipment: the boat is very clean and well-kept. There is a bathroom on board (did not use).  There is bottled water, and you can buy a mixed drink if you want.  The crew: knowledgeable about the area's flora, the wildlife, and the ocean; personable and friendly, funny, and skilled at piloting the craft.  The experience: a great, comfortable boat ride out to a great little spit of land for shell collecting, sponge hunting, beach sitting or wading/swimming.  30 minutes is all you get for this, but we got tons of great shells in that time, and I understand that with multiple trips per day, they want to leave plenty for each group.
# DOLPHINS!  Obviously no one can guarantee you see wild dolphins, but we had the most amazing 15 minute span of time watching a pod of dolphins swim all around the boat, jump, breach, and play.  I mention this more to compliment the company on allowing that much time for the most exciting part of the cruise.  We only started moving again once everyone had gotten to watch for a solid amount of time.  I have no negative comments about the cruise--it was a well managed, clean, safe and fun experience.
#
# Note: the store is pricier than other places in Tarpon Springs' Greektown offering the same sponges and soaps, even with the 20% discount on the cruise ticket.
#
# [496] Came here with some friends on Sunday - I drove separately and their garage was convenient and easy to navigate. I took the elevators straight down to the casino. There are multiple entrances, my friends came from another one. Parking is free on non game days so just fyi. I think it's $40 otherwise since it's so close to the stadiums.
#
# It's really nice on the inside but not many tables per game, maybe it's cause we came on a Sunday? There were only 2 roulette tables that I saw. We played here - the buy in is $25 which I thought was a little pricey. Luckily I broke even which was my hint to stop playing.  I didn't see a waitress come by to the tables with drinks which was disappointing. I might be back if I was in the area but I'm more of a Parx girl
#
# [497] This is a small and intimate museum with surprising amount of collections from many masters. It was a change of scenery from the big box museum such as the Philadelphia Museum of Arts and well worth the time spent.
#
# I particularly liked the ability to aim your phone camera at the paintings and art items and the webpage explaining the artist or the object would come up. It really enhanced the experience
#
# The line in the front can get long and they only give the tickets electronically.  Therefore, I would recommend to buy the ticket online ahead of time and save waiting in line.
#
# [498] Those who have lived North in the Butler-Tarkington, Warfleigh, Meridian-Kessler, and Butler Campus neighborhoods are very familiar with Safeway, but for the Butler students, the newly arrived, or some in many areas of Joan of Arc, St Thomas, IMH, and Christ the King, it may be just far enough from their regular pattern to remain new. Even though it has been there forever. I remember decades ago we would stop there on the way to Rivi. But, after decades of being out of State, I had forgotten about it - and Kincaid's Meat Market across Illinois.
# Safeway does not carry everything, but they also carry more in many areas that most supermarkets. They have a couple of sections throughout the store dedicated to Buy Local. And, I notice they also carry Better options in a number of areas.
# Produce is fresh and well-laid out. Their wide selection of meats from "getting by"  to specialty and higher end cuts. A fabulous dessert and quality ice cream sections. They have brands not normally found in the area from cereal to dairy and snacks. One of their Plains brand cereals is now my go-to.
#
# They are a Union shop, proudly advertised. They keep staff. You don't have to shop there more 3 or 4 times before the regular Staff recognized you.
#
# Prices are a bit higher, but also lower than some others in the neighborhood, and generally not enough higher to waste the gas and Time chasing after it several miles away.
# Kroger's closing their BR store, put a real hole in grocery choices on the Northside. Safeway the covers most every need, with a CVS across 56th for the other hole the Kroger's left.
#
# Especially, Butler students, give it a try. Study their selections. Their dessert selections alone may make Safeway a frequented cupboard...
#
# [499] This place is the hidden treasure down the yellow brick road; you thought didn't exist.
#
# Need literally any kind of tool; tool items never seen anymore in any big box store, and then think about what your grandfather bought; it's in here!
#
# The walkways are certainly not disabled friendly, and barely cleared for those able. Don't take that necessarily as a negative, it's just that you can tell this place had been here just after the Ten Commandments were chiseled... I love places like these and if you ask the owner, he'll tell you if he's got it or not.
#
# Think like, if you take two Ace Hardware's, one Lowes/Home Depot stores (tool section only) and add it to two or three small towns' coolest little tools shops barely on the map, stick them inside of a store barely the size of a modern 7-11 and THIS is Kent's Tools in all of its glory.
#
# Recommend: If you absolutely live near or work this close and need it super fast. Otherwise, the unexpected and extremely steep prices on even rusted tools completely baffles me! I wouldn't have imagined a second hand store would have SOO many costly corroded tools... At least at Harbor Freight you can buy a new item and a warranty for a year for a few bucks more. I loved the store but the over zealous prices are a real turnoff.
#
# [500] Joey is a good cock sucker! Do not buy anything from this shop!
#
# [501] Sad end of an era (?)
# We've been regulars for years here. Football on Sundays.. Lightning games.. and of course BOGO wings on Tuesdays! We were sad to hear it is now "buy one get one 50% off". I guess all good things must end, but what came out was a disappointing tray of tiny wings along with some weird chunks that resembled a wing I suppose. Hoping corporate will rethink this decision, or at least execute some quality control over the product they're delivering. This review gets three stars solely based on our guy behind the bar. Always on top of things even during this short-staffed/supply chain/BOGO NOMO nonsense. Thanks Joe!
#
# [502] Bait and switch from internet pricing. Offered a good truck at a reasonable price, but when it came time to do paperwork it was double the asking price. No explanation,  just said it went from $4970 $7500.  Negotiated price was $5900. Suffice to say i didn't buy the it. Perfect truck bad dealership.  SO PISSED OFF.
#
# [503] The products seem a deal but they are not well made. The king beds in particular are not sold with enough center support and the slats will break sonnet or later ! I suppose they want it to happen after the warranty expires but the product is defective do not buy a bed from them that does not have adequate center support !
#
# [504] We have had Comcast since 2012 have had nothing but problems but when we bought our own modem our service got better I'm mean great buy your own modem and all your problems will go away .Now we only have internet we have a magic jack and all is great so buy your own modem you will glad you did. Flex box is awesome Hulu and Netflix!!!!,
#
# [505] I go to Hung Vuong at least once a week for most Asian groceries. The prices just can't be beaten here. Seriously. Plus, Hung Vuong is a lot bigger than Hmart (the other nearby Asian grocery store), so they consistently carry the most exotic produce and imported shelf items in this area.
#
# Although if you see something you like, stock up because there's no guarantee it will ever be back in stock again. This has happened to me with some of my favorite items in the past (a certain brand of Thai coconut milk and a brand of Filipino cookies).
#
# However, you should be aware of one thing with Hung Vuong's low prices. Some produce could be on the verge of going bad or shelf items slightly past the expiration date. Not everything is like that, but sometimes there are many more than I would expect. So, inspect your fruits and check your dates on items you buy to be on the safe side.
#
# TIP: Be sure to sign up for their rewards program, available at the customer service area. That way, you can get a few bucks off once you spend a certain amount.

# %%
import torch
from sentence_transformers import util

buy_vecs = word_contexts["buy"]
for i in range(len(buy_vecs) - 1):
    sim = util.cos_sim(buy_vecs[i], buy_vecs[i + 1]).item()
    print(f"Context {i} vs {i+1}: cosine similarity = {sim:.3f}")
# Out:
# Context 0 vs 1: cosine similarity = 0.750
# Context 1 vs 2: cosine similarity = 0.727
# Context 2 vs 3: cosine similarity = 0.713

# %%
word_contexts = {}

for idx, text in enumerate(reviews_df["lemmas"]):
    tokens = text.split()
    embeddings = model.encode(tokens, convert_to_tensor=True)
    for token, emb in zip(tokens, embeddings):
        token = token.lower()
        if token not in word_contexts:
            word_contexts[token] = []
        # Store both the embedding and the review index
        word_contexts[token].append((idx, emb))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 5
#       3 for idx, text in enumerate(reviews_df["lemmas"]):
#       4     tokens = text.split()
# ----> 5     embeddings = model.encode(tokens, convert_to_tensor=True)
#       6     for token, emb in zip(tokens, embeddings):
#       7         token = token.lower()
#
# File ~/venvs/python3/lib/python3.10/site-packages/torch/nn/modules/module.py:1964, in Module.__getattr__(self, name)
#    1962     if name in modules:
#    1963         return modules[name]
# -> 1964 raise AttributeError(
#    1965     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1966 )
#
# AttributeError: 'DistilBertModel' object has no attribute 'encode'

# %% [markdown]
# #### ii. Visualize glove word embeddings
# We can visualize similarity in words and observe how Glove model behaves

# %%
# Visualizing gensim pre-trained glove embeddings
# Reduce dimensions with PCA
# From datacamp
pca = PCA(n_components=2, random_state=42)

glove_word_vectors = glove_model[lemmas_in_glove]
glove_word_vectors_2d = pca.fit_transform(glove_word_vectors)

n = 30
glove_word_vectors = glove_word_vectors[:n]
lemmas_in_glove = lemmas_in_glove[:n]
glove_word_vectors_2d = glove_word_vectors_2d[:n]

plt.scatter(glove_word_vectors_2d[:, 0], glove_word_vectors_2d[:, 1], alpha=0.2)
for lemma_in_glove, (x, y) in zip(lemmas_in_glove, glove_word_vectors_2d):
    plt.annotate(lemma_in_glove, (x, y), fontsize=9)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Gensim Pre-trained Glove Embeddings (2D PCA)")
plt.show()

# %%
def get_review_glove_embedding(lemmas, model=glove_model):
    vectors = [glove_model[word] for word in lemmas if word in glove_model]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
tqdm.pandas(desc="Vectorizing review lemmas using Glove pre-trained model", ncols=100)
reviews_pandas_df['glove_embedding'] = reviews_pandas_df['lemma_tokens'].progress_apply(get_review_glove_embedding)

# %%
reviews_pandas_df[['lemmas', 'word_2_vec_embedding', 'glove_embedding']]

# %%
X1 = np.vstack(reviews_pandas_df['word_2_vec_embedding'].values)
print(X1.shape)

X2 = np.vstack(reviews_pandas_df['glove_embedding'].values)
print(X2.shape)



# More complex embeddings: transformers, topic modeling google transformer embeddings
# Different Glove embeddings
# OPenAI, Gemini and HuggingFace

# %%
new_pca = PCA(n_components=2, random_state=42)
w2v_2d = new_pca.fit_transform(X1)
glove_2d = new_pca.fit_transform(X2)

n = 60

# Word2Vec review embeddings plot
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.scatter(w2v_2d[:n, 0], w2v_2d[:n, 1], alpha=0.5)
for i in range(n):
    plt.annotate(str(i), (w2v_2d[i, 0], w2v_2d[i, 1]))
plt.title("Word2Vec Review Embeddings (2D PCA)")

# Glove review embeddings plot
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 2)
plt.scatter(glove_2d[:n, 0], glove_2d[:n, 1], alpha=0.5)
for i in range(n):
    plt.annotate(str(i), (glove_2d[i, 0], glove_2d[i, 1]))
plt.title("Glove Review Embeddings (2D PCA)")

# %%
labels_w2v = kmeans.fit_predict(w2v_2d)

# Word2Vec review embeddings plot
plt.figure(figsize=(14,6))
sns.scatterplot(x=w2v_2d[:, 0], y=w2v_2d[:, 1], alpha=0.5, hue=labels_w2v, palette='tab10')
plt.title("Review Word2Vec Embedding Clusters (2D PCA)")
plt.show()

labels_glove = kmeans.fit_predict(glove_2d)

# Word2Vec review embeddings plot
plt.figure(figsize=(14,6))
sns.scatterplot(x=glove_2d[:, 0], y=glove_2d[:, 1], alpha=0.5, hue=labels_glove, palette='tab10')
plt.title("Review Glove Embedding Clusters (2D PCA)")
plt.show()

# %%
# Set the option to display full column width
pd.set_option('display.max_colwidth', None)

reviews_pandas_df.iloc[[9,18], :][['text', 'lemma_tokens']]

# %%
i, j = 32, 54
cosine_similarity([X1[i]], [X1[j]])

# %%
cosine_similarity([X2[i]], [X2[j]])

# %%
reviews_pandas_df.iloc[[32, 54], :][['text', 'lemma_tokens']]

# %%
n_clusters = 6  # try a few values
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(X2)

reviews_pandas_df["glove_cluster"] = clusters

# %%
reviews_pandas_df[['text', 'glove_cluster']]

# %%
k = 6  # number of clusters
for cluster_id in range(k):
    print(f"\n=== Cluster {cluster_id} ===")
    idxs = np.where(labels_w2v == cluster_id)[0]  # or labels_glove
    for i in idxs[:5]:  # first 5 reviews in this cluster
        print(f"** {reviews_pandas_df['text'].iloc[i]}")

# %%
# Print a few reviews from each cluster
for cluster in sorted(reviews_pandas_df["cluster"].unique()):
    print(f"\n------Cluster {cluster}------\n")
    cluster_revs = reviews_pandas_df[reviews_pandas_df.cluster == cluster]['text'].head(5).values
    for rev in cluster_revs:
        print(f"**{rev}")
