# %%
import os
import pandas as pd

dataset_path = 'yelp_dataset'

# %%
businesses_df = pd.read_json(f'{dataset_path}/yelp_academic_dataset_business.json', lines=True)
businesses_df.shape
# Out:
# (150346, 14)

# %%
# Open vs closed business
businesses_df.is_open.value_counts()
# Out:
# is_open
# 1    119698
# 0     30648
# Name: count, dtype: int64

# %%
# Filter open businesses for our analysis
open_businesses_df = businesses_df[businesses_df.is_open == 1]
open_businesses_df.shape
# Out:
# (119698, 14)

# %% [markdown]
# ### Text Formating
# #### Business names that contain location info

# %%
open_businesses_df[open_businesses_df.name.str.contains(' - ')].head()
# Out:
#                 business_id                                           name  \
# 30   fvWn8oXXwbj2l79cochZyw               Altitude Trampoline Park - Boise
# 142  GWGXTKR0Fhdvzf_isDqJug  David Gower, Jr.  - Coldwell Banker Preferred
# 149  h-y5azB-VlQAT3m7Ff2g2Q                    P's & Q's - Premium Quality
# 202  pmuuoDqNZp7518AUd-YmPA                  Bagelicious - King Of Prussia
# 211  Nh1rc9aSeO-Y5lYmXVS6CA       Quality Inn Nashville Downtown - Stadium
#
#                        address             city state postal_code   latitude  \
# 30         1301 N Milwaukee St            Boise    ID       83704  43.616763
# 142  325 Chestnut St, Ste 1300     Philadelphia    PA       19106  39.949027
# 149                   820 S St     Philadelphia    PA       19147  39.942515
# 202           216 W Beidler Rd  King of Prussia    PA       19406  40.112481
# 211          303 Interstate Dr        Nashville    TN       37213  36.168834
#
#       longitude  stars  review_count  is_open  \
# 30  -116.285382    5.0            30        1
# 142  -75.147190    5.0            17        1
# 149  -75.156468    5.0            16        1
# 202  -75.379975    3.5            60        1
# 211  -86.766911    2.0            53        1
#
#                                             attributes  \
# 30   {'BusinessParking': '{'garage': False, 'street...
# 142  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 149  {'BusinessParking': '{'garage': False, 'street...
# 202  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 211  {'WiFi': ''free'', 'BusinessAcceptsCreditCards...
#
#                                             categories  \
# 30                       Trampoline Parks, Active Life
# 142     Real Estate, Home Services, Real Estate Agents
# 149                  Fashion, Shopping, Men's Clothing
# 202  Restaurants, Bakeries, Caterers, Bagels, Food,...
# 211  Hotels & Travel, Event Planning & Services, Ho...
#
#                                                  hours
# 30   {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...
# 142  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...
# 149                                               None
# 202  {'Tuesday': '7:0-13:0', 'Wednesday': '7:0-13:0...
# 211  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...

# %% [markdown]
# #### Duplicates
# The cell below shows businesses with the same name and location details that we need to treat. We decide on which businesses we need to delete once we have more information (review details) or other details on why we have duplicate businesses.

# %%
# Are there any duplicate businesses? same name, same location
duplicates = open_businesses_df.duplicated(subset=['name', 'address', 'city', 'latitude', 'longitude', 'state', 'is_open'], keep=False)

print(is_open_businesses[duplicates].shape)
is_open_businesses[duplicates].sort_values('name').head(20)
# Out:
# (18, 14)
#                    business_id                                          name  \
# 29874   H55R8ODu9aa51gWnTHLRTw                        Independent Automotive
# 102015  rlwLZhLI7Q8bN3DlSrzW7A                        Independent Automotive
# 25025   YT1ZJrFHgwbeZvzOqSe1LA                                        Kroger
# 126374  BMcyBSKVkaCfKqz-STbvrw                                        Kroger
# 74227   MOay1hDY4AUnnj_6rXHcng  Lake Lawn Metairie Funeral Home & Cemeteries
# 63945   1rC8U1kWIlgkJ33h_MrRpg  Lake Lawn Metairie Funeral Home & Cemeteries
# 113827  aS3iZvJaD8DFnp5Cl7qMWg                              Lakeview Grocery
# 92261   oIozEyiTSYh0T_YQRfpm5A                              Lakeview Grocery
# 11148   SvymuQGYaUSqXmvh5HiPLg                                     Logan Inn
# 57209   8Ck78FmeRO7W9iy1-5eCeg                                     Logan Inn
# 124926  Zl41C3ce-Z0l5vnlEKyQrw                         Robert’s Fresh Market
# 149608  na5KtGdhyBMtkaNrNM2wgQ                         Robert’s Fresh Market
# 141250  9T86OT2VbFeYROxo5fN83A                       Sweet Things Chocolates
# 68      lOP3HxdUTaq0eXhwR_KC-w                       Sweet Things Chocolates
# 48391   aOzeO4vVNXe1YAHXzEq75A                           Tampa Union Station
# 132063  aJnCZAXHc5ydvFpm7EEk8g                           Tampa Union Station
# 49972   Xv3abtQnX83jfZ9PG570YA                            Urology of Indiana
# 147359  3lqGizaxhp_acESSlRD3YQ                            Urology of Indiana
#
#                         address          city state postal_code   latitude  \
# 29874            865 Bergin Way        Sparks    NV       89431  39.526564
# 102015           865 Bergin Way        Sparks    NV       89431  39.526564
# 25025        3410 Gallatin Pike     Nashville    TN       37216  36.210166
# 126374       3410 Gallatin Pike     Nashville    TN       37216  36.210166
# 74227   5100 Pontchartrain Blvd   New Orleans    LA       70124  29.982484
# 63945   5100 Pontchartrain Blvd   New Orleans    LA       70124  29.982484
# 113827         801 Harrison Ave   New Orleans    LA       70124  30.005173
# 92261          801 Harrison Ave   New Orleans    LA       70124  30.005173
# 11148             10 W Ferry St      New Hope    PA       18938  40.363467
# 57209             10 W Ferry St      New Hope    PA       18938  40.363467
# 124926     5016 W Esplanade Ave      Metairie    LA       70006  30.016263
# 149608     5016 W Esplanade Ave      Metairie    LA       70006  30.016263
# 141250           2288 W 86th St  Indianapolis    IN       46260  39.913292
# 68               2288 W 86th St  Indianapolis    IN       46260  39.913292
# 48391        601 N Nebraska Ave         Tampa    FL       33602  27.952747
# 132063       601 N Nebraska Ave         Tampa    FL       33602  27.952747
# 49972      679 E County Line Rd     Greenwood    IN       46143  39.635226
# 147359     679 E County Line Rd     Greenwood    IN       46143  39.635226
#
#          longitude  stars  review_count  is_open  \
# 29874  -119.739034    4.0             5        1
# 102015 -119.739034    4.5            43        1
# 25025   -86.732522    1.5             7        1
# 126374  -86.732522    2.5            41        1
# 74227   -90.114553    4.5            39        1
# 63945   -90.114553    5.0            17        1
# 113827  -90.105275    3.5            48        1
# 92261   -90.105275    3.5            13        1
# 11148   -74.951450    3.0           111        1
# 57209   -74.951450    3.0           153        1
# 124926  -90.199632    3.0            16        1
# 149608  -90.199632    3.0             8        1
# 141250  -86.200830    4.5             6        1
# 68      -86.200830    4.0            13        1
# 48391   -82.450809    3.0            19        1
# 132063  -82.450809    4.0            21        1
# 49972   -86.092537    1.5             8        1
# 147359  -86.092537    2.5            12        1
#
#                                                attributes  \
# 29874              {'BusinessAcceptsCreditCards': 'True'}
# 102015             {'BusinessAcceptsCreditCards': 'True'}
# 25025                                                None
# 126374  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 74227              {'BusinessAcceptsCreditCards': 'True'}
# 63945              {'BusinessAcceptsCreditCards': 'True'}
# 113827  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 92261   {'RestaurantsReservations': 'False', 'Restaura...
# 11148   {'OutdoorSeating': 'True', 'WheelchairAccessib...
# 57209   {'RestaurantsDelivery': 'False', 'WiFi': 'u'fr...
# 124926  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 149608  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 141250  {'Caters': 'True', 'RestaurantsTakeOut': 'True...
# 68      {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 48391                                                None
# 132063                                               None
# 49972   {'ByAppointmentOnly': 'True', 'AcceptsInsuranc...
# 147359  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
#
#                                                categories  \
# 29874        Automotive, Auto Repair, Smog Check Stations
# 102015  Oil Change Stations, Smog Check Stations, Auto...
# 25025                                Shopping, Drugstores
# 126374                                      Grocery, Food
# 74227   Local Flavor, Local Services, Funeral Services...
# 63945   Funeral Services & Cemeteries, Public Services...
# 113827                                      Grocery, Food
# 92261                                Restaurants, Seafood
# 11148   American (New), Restaurants, Seafood, Event Pl...
# 57209   Caterers, Hotels & Travel, Mediterranean, Hote...
# 124926                                      Grocery, Food
# 149608                                      Food, Grocery
# 141250         Chocolatiers & Shops, Food, Specialty Food
# 68      Chocolatiers & Shops, Specialty Food, Candy St...
# 48391     Transportation, Train Stations, Hotels & Travel
# 132063  Train Stations, Local Flavor, Public Services ...
# 49972               Doctors, Health & Medical, Urologists
# 147359              Urologists, Doctors, Health & Medical
#
#                                                     hours
# 29874                                                None
# 102015  {'Monday': '8:0-17:30', 'Tuesday': '8:0-17:30'...
# 25025                                                None
# 126374  {'Monday': '6:0-23:0', 'Tuesday': '6:0-23:0', ...
# 74227   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 63945                                                None
# 113827  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# 92261                                                None
# 11148   {'Wednesday': '16:0-0:0', 'Thursday': '16:0-0:...
# 57209   {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 124926                                               None
# 149608                                               None
# 141250  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 68      {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 48391                                                None
# 132063  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# 49972   {'Monday': '8:0-16:30', 'Tuesday': '8:0-16:30'...
# 147359                                               None

# %%
# Fix dtypes
is_open_businesses = is_open_businesses.astype({
    'stars': 'int64', 
    'business_id': 'string', 
    'name': 'string',
    'address': 'string',
    'city': 'string',
    'state': 'string',
    'postal_code': 'string',
    'is_open': 'category'
})

is_open_businesses.dtypes
# Out:
# business_id     string[python]
# name            string[python]
# address         string[python]
# city            string[python]
# state           string[python]
# postal_code     string[python]
# latitude               float64
# longitude              float64
# stars                    int64
# review_count             int64
# is_open               category
# attributes              object
# categories              object
# hours                   object
# dtype: object

# %%
# Dataframe info
is_open_businesses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119698 entries, 1 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   119698 non-null  string
#  1   name          119698 non-null  string
#  2   address       119698 non-null  string
#  3   city          119698 non-null  string
#  4   state         119698 non-null  string
#  5   postal_code   119698 non-null  string
#  6   latitude      119698 non-null  float64
#  7   longitude     119698 non-null  float64
#  8   stars         119698 non-null  int64
#  9   review_count  119698 non-null  int64
#  10  is_open       119698 non-null  int64
#  11  attributes    107350 non-null  object
#  12  categories    119603 non-null  object
#  13  hours         103603 non-null  object
# dtypes: float64(2), int64(3), object(3), string(6)
# memory usage: 13.7+ MB

# %%
# Some secondaru info is missing in the data, but we won't bother just yet.

# %% [markdown]
# #### Future data processing items
# Our analysis is on textual sentiment extraction, so we'll leave the remaining collapsed columns attributes, categories, hours unless we need them during EDA

# %%
# Print column dtypes
businesses_df.dtypes

# stars to numeric/int64
# how many closed businesses
# business id to text
# name to text and normalize 'correct misspellings'; if doing location-based analysis
# Need to round/normalize to get more dupicates gone?
# is_open to category?
# Out:
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# attributes       object
# categories       object
# hours            object
# dtype: object
