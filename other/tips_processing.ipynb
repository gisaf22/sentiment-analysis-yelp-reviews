# %% [markdown]
# ### Semantic Analysis of Yelp Businesses' Tips
# We will be using a json file that's part of Yelp's distributed user reviews and tips on businesses.
# This file contains over 900k user tips for businesses across mostly the U.S(Canada as well).
# Each tip has an associated user_id, business_id, timestamp, compliment_count from other users.
# GOAL: Build a model that generalizes well the sentiment behind each tip/review
# We can leverage tips collected from users to enrich our analysis and recommend what's liked and not liked by users

# %%
import os
import nltk
import pandas as pd
import contractions
import string

from nltk import word_tokenize, sent_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, wordnet

from bs4 import BeautifulSoup, MarkupResemblesLocatorWarning
import warnings
from unidecode import unidecode

# Ignore spurious warnings about URL-looking markup
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

pd.set_option('display.max_colwidth', None) 

dataset_path = 'yelp_dataset'

# Download required NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')

# Get English stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/safarifgisa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/safarifgisa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/safarifgisa/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
from html.parser import HTMLParser

# %%
class TxtStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ' '.join(self.fed)
        
    # Normalize special accented characters and 
    # convert them into regular ASCII characters so as to standardize the text across all documents
    def normalize_accented_characters(text):
        text = unicodedata.normalize('NFKD', text.decode('utf-8')).encode('ascii', 'ignore')
        return text
        
def strip_html(text):
    html_stripper = TxtStripper()
    html_stripper.feed(text)
    return html_stripper.get_data()

# %%
def normalize_corpus(corpus, lemmatize=True, only_text_chars=False, tokenize=False):
    normalized_corpus = []
    for index, text in enumerate(corpus):
        text = normalize_accented_characters(text)
        text = html_parser.unescape(text)
        text = strip_html(text)
        text = expand_contractions(text, CONTRACTION_MAP)
        if lemmatize:
            text = lemmatize_text(text)
        else:
            text = text.lower()
            text = remove_special_characters(text)
            text = remove_stopwords(text)
            if only_text_chars:
                text = keep_text_characters(text)
            if tokenize:
                text = tokenize_text(text)
                normalized_corpus.append(text)
            else:
                normalized_corpus.append(text)
    return normalized_cor

# %% [markdown]
# ### Load user tips

# %%
tips_df = pd.read_json(f'{dataset_path}/yelp_academic_dataset_tip.json', lines=True)
tips_df.shape
# Out:
# (908915, 5)

# %%
tips_df.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                         text  \
# 0                             Avengers time with the ladies.
# 1  They have lots of good deserts and tasty cuban sandwiches
# 2                     It's open even when you think it isn't
# 3                                  Very decent fried chicken
# 4                     Appetizers.. platter special for lunch
#
#                  date  compliment_count
# 0 2012-05-18 02:17:21                 0
# 1 2013-02-05 18:35:10                 0
# 2 2013-08-18 00:56:08                 0
# 3 2017-06-27 23:05:38                 0
# 4 2012-10-06 19:43:09                 0

# %%
# 1. Remove HTML tags
def strip_html_tags_and_whitespace(text):
    soup = BeautifulSoup(text, "html.parser")
    if bool(soup.find()):
        [s.extract() for s in soup(['iframe', 'script'])]
        stripped_text = soup.get_text()
        stripped_text = re.sub(r'\r\n?|\n', '\n', stripped_text)
    else:
        stripped_text = text
    return stripped_text

tips_cleaned_df = tips_df.copy()
tips_cleaned_df['tip_cleaned'] = tips_cleaned_df.text.apply(lambda t: strip_html_tags_and_whitespace(t))

# %% [markdown]
# ## Text processing
# ### Remove multiple whitespace
# We remove all leading and trailing whitespace and replace multiple whitespace with just a single whitespace. Replace '\t', '\n', '\r' with one whitespace.

# %%
# 2. Trim and collapse multiple whitespaces
tips_cleaned_df['tip_cleaned'] = tips_cleaned_df.tip_cleaned.str.replace(r"\s+", " ", regex=True)
tips_cleaned_df['tip_cleaned'] = tips_cleaned_df['tip_cleaned'].str.strip()

# %%
tips_cleaned_df[tips_cleaned_df.text.str.contains('\n')].head(5)
# Out:
#                     user_id             business_id  \
# 79   bsNS8tvMDn9ntB8OP3rNsw  i1A9_CvPb0SZ_5nTddCEgA
# 106  2GqQGWRmasX8qDuG7CDiWg  pTMi7h7JMtwSsijdx_BPDg
# 112  9r0RoGmf7211qmiLZsgYeg  WMkiheTT-8kRslImVLWMVw
# 175  gYeiI_21LzFWidjHbNkiyQ  ikONTzFKwachQtFtoMGeIQ
# 191  kKPbWlBjpSL3Qzvtn_AaPw  j4kYliTkKf7k-oDqVgyXYA
#
#                                                                                                                                                                                                                                                                                                                                                                                                 text  \
# 79                                                                                                                                                                                                                                                Great hoagies, great bread!  Cutlets....meh\n\nMy go to sandwich: A Cut Above Italian w/ oil/vinegar, l/t/o, hot peppers, sweet peppers, & pickles
# 106                                                                                                                                                                                                                                                                                                       Probably the best pizza in the area.\nOn Wednesday 4-8 the large round pies are half price
# 112  The all local beers is a def plus!\nI had the garlic shrimp with garlic bread and my wife had the duck salad. The portions are decent and the duck was excellent, nice crispy but not burnt skin and the meat was perfect not overdone. My shrimp was good, a bit over seasoned, however not too much, nice size pieces and really good with the sauce. I would def go back, it's worth a look!
# 175                                                                                                                                                                                                                                                                                                                                                Pint and pizza slice for\n$5.95 is the way to go!
# 191                                                                                                                                                                                              Mandrakes & Tree-nuts\nCollege Football Championship\nBig Lights of Texas\n\n#NOLA_Haiku haiku\n#OSUvsORE #Buckeyes #NCAA\n#NationalChampionship\n#THEOhioStateUniversity\n#ATTStadium #OSUBuckeyes
#
#                    date  compliment_count  \
# 79  2014-03-13 16:39:55                 0
# 106 2017-06-22 12:04:47                 0
# 112 2013-06-20 23:50:52                 0
# 175 2015-05-23 23:52:44                 0
# 191 2015-01-13 03:44:02                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                         tip_cleaned
# 79                                                                                                                                                                                                                                                   Great hoagies, great bread! Cutlets....meh My go to sandwich: A Cut Above Italian w/ oil/vinegar, l/t/o, hot peppers, sweet peppers, & pickles
# 106                                                                                                                                                                                                                                                                                                       Probably the best pizza in the area. On Wednesday 4-8 the large round pies are half price
# 112  The all local beers is a def plus! I had the garlic shrimp with garlic bread and my wife had the duck salad. The portions are decent and the duck was excellent, nice crispy but not burnt skin and the meat was perfect not overdone. My shrimp was good, a bit over seasoned, however not too much, nice size pieces and really good with the sauce. I would def go back, it's worth a look!
# 175                                                                                                                                                                                                                                                                                                                                                Pint and pizza slice for $5.95 is the way to go!
# 191                                                                                                                                                                                                      Mandrakes & Tree-nuts College Football Championship Big Lights of Texas #NOLA_Haiku haiku #OSUvsORE #Buckeyes #NCAA #NationalChampionship #THEOhioStateUniversity #ATTStadium #OSUBuckeyes

# %% [markdown]
# #### Replaced accented characters
# This step is recommended when using traditional ML NLP models, where as Deep Leearning models or embeddings would be fine without this step. We'll use it for now! (e.g "café" → "cafe")

# %%
# 3. Normalize accented characters
tips_cleaned_df.tip_cleaned = tips_cleaned_df.tip_cleaned.apply(unidecode)

# %% [markdown]
# #### 4. Contraction Expansion
# The next step is to expand contractions, meaning words like 'He's' -> 'He is', 'Don't' -> 'do not'. We need consistency and uniformity in our tokens which helps during lemmatization and interpreting negations when we get to extracting meaning and topics from user reviews.

# %%
tips_cleaned_df['tip_cleaned'] = tips_cleaned_df['tip_cleaned'].apply(lambda tip: contractions.fix(tip))
tips_cleaned_df.head(1)
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
#
#                              text                date  compliment_count  \
# 0  Avengers time with the ladies. 2012-05-18 02:17:21                 0
#
#                       tip_cleaned
# 0  Avengers time with the ladies.

# %% [markdown]
# #### Lower casing
# Next step is to lower all text to help with tokenization and other downstream processes

# %%
# Lower all tips text
tips_cleaned_df['tip_cleaned'] = tips_cleaned_df['tip_cleaned'].str.lower()
tips_cleaned_df.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                         text  \
# 0                             Avengers time with the ladies.
# 1  They have lots of good deserts and tasty cuban sandwiches
# 2                     It's open even when you think it isn't
# 3                                  Very decent fried chicken
# 4                     Appetizers.. platter special for lunch
#
#                  date  compliment_count  \
# 0 2012-05-18 02:17:21                 0
# 1 2013-02-05 18:35:10                 0
# 2 2013-08-18 00:56:08                 0
# 3 2017-06-27 23:05:38                 0
# 4 2012-10-06 19:43:09                 0
#
#                                                  tip_cleaned
# 0                             avengers time with the ladies.
# 1  they have lots of good deserts and tasty cuban sandwiches
# 2                   it is open even when you think it is not
# 3                                  very decent fried chicken
# 4                     appetizers.. platter special for lunch

# %% [markdown]
# #### Tokenization
# I am interested in more nuanced, or sentence theme extraction, thus keeping sentence tokens. Word tokenization is performed on each sentence as opposed to the whole tip. Extracting words from user reviews is what we call Tokenization.

# %%
# Word tokenizer
tips_cleaned_df['sent_tokens'] = tips_cleaned_df.tip_cleaned.apply(lambda t: sent_tokenize(t))
tips_cleaned_df['sent_word_tokens'] = tips_cleaned_df.sent_tokens.apply(lambda sents: [word_tokenize(sent) for sent in sents])

tips_cleaned_df.head(20)
# Out:
#                    user_id             business_id  \
# 0   AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1   NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2   -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3   FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4   ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 5   trf3Qcz8qvCDKXiTgjUcEg  7Rm9Ba50bw23KTA8RedZYg
# 6   SMGAlRjyfuYu-c-22zIyOg  kH-0iXqkL7b8UXNpguBMKg
# 7   YVBB9g23nuVJ0u44zK0pSA  jtri188kuhe_AuEOJ51U_A
# 8   VL12EhEdT4OWqGq0nIqkzw  xODBZmX4EmlVvbqtKN7YKg
# 9   4ay-fdVks5WMerYL_htkGQ  pICJRcyqW1cF96Q3XhLSbw
# 10  OttfcRxgRrYsTg9EV5Aozg  clwjLY7PdYJpe7IP9lrqEw
# 11  JsXhBw6MntzTJjH_Ue5udw  wLHodvVFLTgK3nl2XG8OCw
# 12  Y0JfJh4B-jrtGc_AHfWi6w  wUMuvdUeVZODZk7TjaD2jg
# 13  MlnuJ7T14CE0JDK2ZIOx5g  MDr7KLYSPkEonvGojNEMBw
# 14  ffWWVlmsrN5lZ6sjAE-vTw  aK6R2akvIK9ijw3FvDy8vw
# 15  j2sEA3hiUcwHfq9Ml6M47g  EXYbKA1tocvOK_1tXxZXLA
# 16  jsaN4TDygu76AGTiB3PpBA  H9fkf4Xkj_j7Zxs1FmY58Q
# 17  kjFgyrCvmVVGSlgWzRXILw  ReX09lhufLTAx19krkltDA
# 18  I6aRZ4sE7ixv0_2r3-XvGw  c5nLy7YgXG-IIrOmqJv1nA
# 19  Ll5l4WTKPH7zWQWA68Rhdw  LJaR65ALpz261_dlVWqV2g
#
#                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                 Avengers time with the ladies.
# 1                                                                                                                                                      They have lots of good deserts and tasty cuban sandwiches
# 2                                                                                                                                                                         It's open even when you think it isn't
# 3                                                                                                                                                                                      Very decent fried chicken
# 4                                                                                                                                                                         Appetizers.. platter special for lunch
# 5                                                                                                                   Chili Cup + Single Cheeseburger with onion, pickle, and relish + Vanilla Coca-Cola...so far.
# 6   Saturday, Dec 7th 2013, ride Patco's Silver Sleigh w/ Santa & his elves on a decorated train into Center City. Trains leave from Lindenwold at 10am, 11:15am, & 12:30pm, and make all stops. Great for kids!
# 7                                                                                                                               This is probably the best place in the cool Springs area to watch a game and eat
# 8                                                                                                                                                                                                          Tacos
# 9                                                                                                                                               Starbucks substitute in boring downtown Tampa. Ugh. Never again!
# 10                                                                                                                                                                                       Order the Tortilla Soup
# 11                                                                                                                                                                    Very good will definitely be coming back!!
# 12                                                                                                                                                                       If the Hotlight is on you must stop in.
# 13                                                                                                                                                                                             Let's go Yankees!
# 14                                                                                                                                                                    Basically same food as rally's for $5 more
# 15                                                                        Don't go for dinner. They close at 6. Really Yvonne L? Negative stars for a restaurant where you you didn't and never intended to eat?
# 16                                                                                                                                                                       30 mins for take out. Right right tight
# 17                                                                                      Got the grilled chicken entree. It was delicious but was a small portion. I like the environment here, for sure, though.
# 18                                                                                                                                               This is the bomb ! I love this dish. Try it you'll like it !lol
# 19                                                                                                                                                                                Helping Mona find a new phone.
#
#                   date  compliment_count  \
# 0  2012-05-18 02:17:21                 0
# 1  2013-02-05 18:35:10                 0
# 2  2013-08-18 00:56:08                 0
# 3  2017-06-27 23:05:38                 0
# 4  2012-10-06 19:43:09                 0
# 5  2012-03-13 04:00:52                 0
# 6  2013-12-03 23:42:15                 0
# 7  2016-11-22 22:14:58                 0
# 8  2012-07-27 01:48:24                 0
# 9  2012-06-09 22:57:04                 0
# 10 2014-06-17 01:20:14                 0
# 11 2017-03-23 22:01:41                 0
# 12 2013-02-28 02:05:54                 0
# 13 2011-07-20 21:52:57                 0
# 14 2014-06-12 17:34:20                 0
# 15 2011-10-13 03:15:15                 0
# 16 2012-03-11 23:16:12                 0
# 17 2013-06-10 20:18:41                 0
# 18 2016-04-23 02:44:03                 0
# 19 2012-06-02 14:39:28                 0
#
#                                                                                                                                                                                                      tip_cleaned  \
# 0                                                                                                                                                                                 avengers time with the ladies.
# 1                                                                                                                                                      they have lots of good deserts and tasty cuban sandwiches
# 2                                                                                                                                                                       it is open even when you think it is not
# 3                                                                                                                                                                                      very decent fried chicken
# 4                                                                                                                                                                         appetizers.. platter special for lunch
# 5                                                                                                                   chili cup + single cheeseburger with onion, pickle, and relish + vanilla coca-cola...so far.
# 6   saturday, dec 7th 2013, ride patco's silver sleigh w/ santa & his elves on a decorated train into center city. trains leave from lindenwold at 10am, 11:15am, & 12:30pm, and make all stops. great for kids!
# 7                                                                                                                               this is probably the best place in the cool springs area to watch a game and eat
# 8                                                                                                                                                                                                          tacos
# 9                                                                                                                                               starbucks substitute in boring downtown tampa. ugh. never again!
# 10                                                                                                                                                                                       order the tortilla soup
# 11                                                                                                                                                                    very good will definitely be coming back!!
# 12                                                                                                                                                                       if the hotlight is on you must stop in.
# 13                                                                                                                                                                                            let us go yankees!
# 14                                                                                                                                                                    basically same food as rally's for $5 more
# 15                                                                      do not go for dinner. they close at 6. really yvonne l? negative stars for a restaurant where you you did not and never intended to eat?
# 16                                                                                                                                                                       30 mins for take out. right right tight
# 17                                                                                      got the grilled chicken entree. it was delicious but was a small portion. i like the environment here, for sure, though.
# 18                                                                                                                                             this is the bomb ! i love this dish. try it you will like it !lol
# 19                                                                                                                                                                                helping mona find a new phone.
#
#                                                                                                                                                                                                          sent_tokens  \
# 0                                                                                                                                                                                   [avengers time with the ladies.]
# 1                                                                                                                                                        [they have lots of good deserts and tasty cuban sandwiches]
# 2                                                                                                                                                                         [it is open even when you think it is not]
# 3                                                                                                                                                                                        [very decent fried chicken]
# 4                                                                                                                                                                           [appetizers.. platter special for lunch]
# 5                                                                                                                     [chili cup + single cheeseburger with onion, pickle, and relish + vanilla coca-cola...so far.]
# 6   [saturday, dec 7th 2013, ride patco's silver sleigh w/ santa & his elves on a decorated train into center city., trains leave from lindenwold at 10am, 11:15am, & 12:30pm, and make all stops., great for kids!]
# 7                                                                                                                                 [this is probably the best place in the cool springs area to watch a game and eat]
# 8                                                                                                                                                                                                            [tacos]
# 9                                                                                                                                               [starbucks substitute in boring downtown tampa., ugh., never again!]
# 10                                                                                                                                                                                         [order the tortilla soup]
# 11                                                                                                                                                                    [very good will definitely be coming back!, !]
# 12                                                                                                                                                                         [if the hotlight is on you must stop in.]
# 13                                                                                                                                                                                              [let us go yankees!]
# 14                                                                                                                                                                      [basically same food as rally's for $5 more]
# 15                                                                      [do not go for dinner., they close at 6. really yvonne l?, negative stars for a restaurant where you you did not and never intended to eat?]
# 16                                                                                                                                                                        [30 mins for take out., right right tight]
# 17                                                                                      [got the grilled chicken entree., it was delicious but was a small portion., i like the environment here, for sure, though.]
# 18                                                                                                                                             [this is the bomb !, i love this dish., try it you will like it !lol]
# 19                                                                                                                                                                                  [helping mona find a new phone.]
#
#                                                                                                                                                                                                                                                              sent_word_tokens
# 0                                                                                                                                                                                                                                    [[avengers, time, with, the, ladies, .]]
# 1                                                                                                                                                                                                      [[they, have, lots, of, good, deserts, and, tasty, cuban, sandwiches]]
# 2                                                                                                                                                                                                                       [[it, is, open, even, when, you, think, it, is, not]]
# 3                                                                                                                                                                                                                                            [[very, decent, fried, chicken]]
# 4                                                                                                                                                                                                                            [[appetizers, .., platter, special, for, lunch]]
# 5                                                                                                                                                     [[chili, cup, +, single, cheeseburger, with, onion, ,, pickle, ,, and, relish, +, vanilla, coca-cola, ..., so, far, .]]
# 6   [[saturday, ,, dec, 7th, 2013, ,, ride, patco, 's, silver, sleigh, w/, santa, &, his, elves, on, a, decorated, train, into, center, city, .], [trains, leave, from, lindenwold, at, 10am, ,, 11:15am, ,, &, 12:30pm, ,, and, make, all, stops, .], [great, for, kids, !]]
# 7                                                                                                                                                                        [[this, is, probably, the, best, place, in, the, cool, springs, area, to, watch, a, game, and, eat]]
# 8                                                                                                                                                                                                                                                                   [[tacos]]
# 9                                                                                                                                                                                      [[starbucks, substitute, in, boring, downtown, tampa, .], [ugh, .], [never, again, !]]
# 10                                                                                                                                                                                                                                             [[order, the, tortilla, soup]]
# 11                                                                                                                                                                                                                 [[very, good, will, definitely, be, coming, back, !], [!]]
# 12                                                                                                                                                                                                                      [[if, the, hotlight, is, on, you, must, stop, in, .]]
# 13                                                                                                                                                                                                                                                [[let, us, go, yankees, !]]
# 14                                                                                                                                                                                                                  [[basically, same, food, as, rally, 's, for, $, 5, more]]
# 15                                                                                           [[do, not, go, for, dinner, .], [they, close, at, 6., really, yvonne, l, ?], [negative, stars, for, a, restaurant, where, you, you, did, not, and, never, intended, to, eat, ?]]
# 16                                                                                                                                                                                                                     [[30, mins, for, take, out, .], [right, right, tight]]
# 17                                                                                                             [[got, the, grilled, chicken, entree, .], [it, was, delicious, but, was, a, small, portion, .], [i, like, the, environment, here, ,, for, sure, ,, though, .]]
# 18                                                                                                                                                                               [[this, is, the, bomb, !], [i, love, this, dish, .], [try, it, you, will, like, it, !, lol]]
# 19                                                                                                                                                                                                                                  [[helping, mona, find, a, new, phone, .]]

# %% [markdown]
# #### Lemmatize tokens
# Next step, is to compute lemmas of the clean tokens we created from each user review. Lemmatization finds the base form, as opposed to stemming which finds the root form of a word. The meaning of a word is important to semantic analysis, therefore, we use POS tags to enhance lemmatization by identifying the nature of the word.

# %%
# Map POS tags (nltk) to WordNet POS tags
def map_to_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        # Default
        return wordnet.NOUN

lemmatizer = WordNetLemmatizer()

def lemmatize_sent_word_tagged_tokens(sent_word_tokens):
    lemmatized_sentences = []
    for sent in sent_word_tokens:
        pos_tags = pos_tag(sent)
        lemmas = (lemmatizer.lemmatize(token, map_to_wordnet_pos(token)) for token, tag in pos_tags)
        lemmatized_sentences.append(list(lemmas))
    return lemmatized_sentences

# Lemmatize sent_word_tokens
tips_cleaned_df['lemmas'] = tips_cleaned_df.sent_word_tokens.apply(lemmatize_sent_word_tagged_tokens)

# %%
tips_cleaned_df.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                         text  \
# 0                             Avengers time with the ladies.
# 1  They have lots of good deserts and tasty cuban sandwiches
# 2                     It's open even when you think it isn't
# 3                                  Very decent fried chicken
# 4                     Appetizers.. platter special for lunch
#
#                  date  compliment_count  \
# 0 2012-05-18 02:17:21                 0
# 1 2013-02-05 18:35:10                 0
# 2 2013-08-18 00:56:08                 0
# 3 2017-06-27 23:05:38                 0
# 4 2012-10-06 19:43:09                 0
#
#                                                  tip_cleaned  \
# 0                             avengers time with the ladies.
# 1  they have lots of good deserts and tasty cuban sandwiches
# 2                   it is open even when you think it is not
# 3                                  very decent fried chicken
# 4                     appetizers.. platter special for lunch
#
#                                                    sent_tokens  \
# 0                             [avengers time with the ladies.]
# 1  [they have lots of good deserts and tasty cuban sandwiches]
# 2                   [it is open even when you think it is not]
# 3                                  [very decent fried chicken]
# 4                     [appetizers.. platter special for lunch]
#
#                                                          sent_word_tokens  \
# 0                                [[avengers, time, with, the, ladies, .]]
# 1  [[they, have, lots, of, good, deserts, and, tasty, cuban, sandwiches]]
# 2                   [[it, is, open, even, when, you, think, it, is, not]]
# 3                                        [[very, decent, fried, chicken]]
# 4                        [[appetizers, .., platter, special, for, lunch]]
#
#                                                                lemmas
# 0                               [[avenger, time, with, the, lady, .]]
# 1  [[they, have, lot, of, good, desert, and, tasty, cuban, sandwich]]
# 2               [[it, is, open, even, when, you, think, it, is, not]]
# 3                                    [[very, decent, fried, chicken]]
# 4                     [[appetizer, .., platter, special, for, lunch]]

# %% [markdown]
# #### Stopword removal
# Lemmas produced from the step above, contain unimportant words and punctuation that isn't important to our analysis. Therefore, we need to remove careful all words in the set of stopwords from nltk. However, negative is an important subset that we need.

# %%
# keep these negations
negations = {'not', 'no', 'non', 'never', 'none', 'nobody', 'nothing', 'neither'}
stop_words = set(stopwords.words('english')) - negations

# Remove non alphabetic lemmas
tips_cleaned_df['lemmas_no_stop'] = tips_cleaned_df.lemmas.apply(
    lambda lemmas_sents: [[lemma for lemma in lemmas_sent if lemma not in stop_words and lemma.isalpha()] for lemmas_sent in lemmas_sents])

# %%
tips_cleaned_df.head(30)
# Out:
#                    user_id             business_id  \
# 0   AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1   NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2   -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3   FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4   ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 5   trf3Qcz8qvCDKXiTgjUcEg  7Rm9Ba50bw23KTA8RedZYg
# 6   SMGAlRjyfuYu-c-22zIyOg  kH-0iXqkL7b8UXNpguBMKg
# 7   YVBB9g23nuVJ0u44zK0pSA  jtri188kuhe_AuEOJ51U_A
# 8   VL12EhEdT4OWqGq0nIqkzw  xODBZmX4EmlVvbqtKN7YKg
# 9   4ay-fdVks5WMerYL_htkGQ  pICJRcyqW1cF96Q3XhLSbw
# 10  OttfcRxgRrYsTg9EV5Aozg  clwjLY7PdYJpe7IP9lrqEw
# 11  JsXhBw6MntzTJjH_Ue5udw  wLHodvVFLTgK3nl2XG8OCw
# 12  Y0JfJh4B-jrtGc_AHfWi6w  wUMuvdUeVZODZk7TjaD2jg
# 13  MlnuJ7T14CE0JDK2ZIOx5g  MDr7KLYSPkEonvGojNEMBw
# 14  ffWWVlmsrN5lZ6sjAE-vTw  aK6R2akvIK9ijw3FvDy8vw
# 15  j2sEA3hiUcwHfq9Ml6M47g  EXYbKA1tocvOK_1tXxZXLA
# 16  jsaN4TDygu76AGTiB3PpBA  H9fkf4Xkj_j7Zxs1FmY58Q
# 17  kjFgyrCvmVVGSlgWzRXILw  ReX09lhufLTAx19krkltDA
# 18  I6aRZ4sE7ixv0_2r3-XvGw  c5nLy7YgXG-IIrOmqJv1nA
# 19  Ll5l4WTKPH7zWQWA68Rhdw  LJaR65ALpz261_dlVWqV2g
# 20  FQ-zmWPEG_pjSQx6pt3Efw  3ZynJ94VpIdDlaArmEp2Rg
# 21  1viszljzsa8W7VnYPuWosw  Zg83olSjsdXAhE5EEy5IcQ
# 22  phKNHTaokisQkZ7qQbxryA  pWuoHHu0LuVrD0HjadDygg
# 23  Ba1I_wRHRQzvuyFU4PwPrw  ZhCnKe7U1TsHWnAlXl8Isw
# 24  tA1U-XSh9woo73eQmWGyAQ  xHwvbm1SJwtaZtOZzFQcmQ
# 25  bjX58cooXPxdNfR0GZ6r9Q  M1hsyjJDdQQeNP164FJ1pA
# 26  VQro7KJpsspqEO68ilIJAw  FpwmIq3Gpo6hGIrOOv8lTw
# 27  BC2LVfzoizlY4kJPzi_13Q  tkDs-InBqql7rqlAan97vA
# 28  CozGguiwx7JEVk7cAwdvpA  ghsaIqQ1xY3cWtWWJ4QW5w
# 29  e67fm29pOiQUcPSltCAHVA  vaYy-IWyfh1ILji0l2TpzQ
#
#                                                                                                                                                                                                                            text  \
# 0                                                                                                                                                                                                Avengers time with the ladies.
# 1                                                                                                                                                                     They have lots of good deserts and tasty cuban sandwiches
# 2                                                                                                                                                                                        It's open even when you think it isn't
# 3                                                                                                                                                                                                     Very decent fried chicken
# 4                                                                                                                                                                                        Appetizers.. platter special for lunch
# 5                                                                                                                                  Chili Cup + Single Cheeseburger with onion, pickle, and relish + Vanilla Coca-Cola...so far.
# 6                  Saturday, Dec 7th 2013, ride Patco's Silver Sleigh w/ Santa & his elves on a decorated train into Center City. Trains leave from Lindenwold at 10am, 11:15am, & 12:30pm, and make all stops. Great for kids!
# 7                                                                                                                                              This is probably the best place in the cool Springs area to watch a game and eat
# 8                                                                                                                                                                                                                         Tacos
# 9                                                                                                                                                              Starbucks substitute in boring downtown Tampa. Ugh. Never again!
# 10                                                                                                                                                                                                      Order the Tortilla Soup
# 11                                                                                                                                                                                   Very good will definitely be coming back!!
# 12                                                                                                                                                                                      If the Hotlight is on you must stop in.
# 13                                                                                                                                                                                                            Let's go Yankees!
# 14                                                                                                                                                                                   Basically same food as rally's for $5 more
# 15                                                                                       Don't go for dinner. They close at 6. Really Yvonne L? Negative stars for a restaurant where you you didn't and never intended to eat?
# 16                                                                                                                                                                                      30 mins for take out. Right right tight
# 17                                                                                                     Got the grilled chicken entree. It was delicious but was a small portion. I like the environment here, for sure, though.
# 18                                                                                                                                                              This is the bomb ! I love this dish. Try it you'll like it !lol
# 19                                                                                                                                                                                               Helping Mona find a new phone.
# 20                                                                                                                                                                                       Yes, I'm eating here again. Breakfast!
# 21                                                                                                                                                                                       Order crispy and they bake it up good.
# 22                                                                                                                                                                                                             Crepes please!!!
# 23                                                                                               The pimento cheese tastes great and is a large portion for a starter - great for sharing!  The fried pickles are also awesome!
# 24  If you haven't  been here in a good while or if you are used to the same place on the west coast called, Carl Jr. (both are applicable to me), please don't  come here for the turkey burger.  It is no longer on the menu.
# 22                                                                                                                                                                                                            crepes please!!!
# 23                                                                                               the pimento cheese tastes great and is a large portion for a starter - great for sharing! the fried pickles are also awesome!
# 24  if you have not been here in a good while or if you are used to the same place on the west coast called, carl jr. (both are applicable to me), please do not come here for the turkey burger. it is no longer on the menu.
# 25                                                                                                                                                                                                        everything is yummy!
# 26                                                                                                                                                                                    allow yourself time to wait on your food
# 27                                                                                                                                                                            looks like mini burgers, similar to white castle
# 28                                                                                                                                                                                                                 icky on tap
# 29                                                                                                                                                                           great breakfast buffet open to the public also ;)
#
#                                                                                                                                                                                                                       sent_tokens  \
# 0                                                                                                                                                                                                [avengers time with the ladies.]
# 1                                                                                                                                                                     [they have lots of good deserts and tasty cuban sandwiches]
# 2                                                                                                                                                                                      [it is open even when you think it is not]
# 3                                                                                                                                                                                                     [very decent fried chicken]
# 4                                                                                                                                                                                        [appetizers.. platter special for lunch]
# 5                                                                                                                                  [chili cup + single cheeseburger with onion, pickle, and relish + vanilla coca-cola...so far.]
# 6                [saturday, dec 7th 2013, ride patco's silver sleigh w/ santa & his elves on a decorated train into center city., trains leave from lindenwold at 10am, 11:15am, & 12:30pm, and make all stops., great for kids!]
# 7                                                                                                                                              [this is probably the best place in the cool springs area to watch a game and eat]
# 8                                                                                                                                                                                                                         [tacos]
# 9                                                                                                                                                            [starbucks substitute in boring downtown tampa., ugh., never again!]
# 10                                                                                                                                                                                                      [order the tortilla soup]
# 11                                                                                                                                                                                 [very good will definitely be coming back!, !]
# 12                                                                                                                                                                                      [if the hotlight is on you must stop in.]
# 13                                                                                                                                                                                                           [let us go yankees!]
# 14                                                                                                                                                                                   [basically same food as rally's for $5 more]
# 15                                                                                   [do not go for dinner., they close at 6. really yvonne l?, negative stars for a restaurant where you you did not and never intended to eat?]
# 16                                                                                                                                                                                     [30 mins for take out., right right tight]
# 17                                                                                                   [got the grilled chicken entree., it was delicious but was a small portion., i like the environment here, for sure, though.]
# 18                                                                                                                                                          [this is the bomb !, i love this dish., try it you will like it !lol]
# 19                                                                                                                                                                                               [helping mona find a new phone.]
# 20                                                                                                                                                                                     [yes, i am eating here again., breakfast!]
# 21                                                                                                                                                                                       [order crispy and they bake it up good.]
# 22                                                                                                                                                                                                           [crepes please!!, !]
# 23                                                                                               [the pimento cheese tastes great and is a large portion for a starter - great for sharing!, the fried pickles are also awesome!]
# 24  [if you have not been here in a good while or if you are used to the same place on the west coast called, carl jr. (both are applicable to me), please do not come here for the turkey burger., it is no longer on the menu.]
# 25                                                                                                                                                                                                         [everything is yummy!]
# 26                                                                                                                                                                                     [allow yourself time to wait on your food]
# 27                                                                                                                                                                             [looks like mini burgers, similar to white castle]
# 28                                                                                                                                                                                                                  [icky on tap]
# 29                                                                                                                                                                            [great breakfast buffet open to the public also ;)]
#
#                                                                                                                                                                                                                                                                               sent_word_tokens  \
# 0                                                                                                                                                                                                                                                     [[avengers, time, with, the, ladies, .]]
# 1                                                                                                                                                                                                                       [[they, have, lots, of, good, deserts, and, tasty, cuban, sandwiches]]
# 27                                                                                                                                                                                                                                 [[look, like, mini, burger, ,, similar, to, white, castle]]
# 28                                                                                                                                                                                                                                                                           [[icky, on, tap]]
# 29                                                                                                                                                                                                                             [[great, breakfast, buffet, open, to, the, public, also, ;, )]]
#
#                                                                                                                                       lemmas_no_stop
# 0                                                                                                                            [[avenger, time, lady]]
# 1                                                                                                      [[lot, good, desert, tasty, cuban, sandwich]]
# 2                                                                                                                         [[open, even, think, not]]
# 3                                                                                                                         [[decent, fried, chicken]]
# 4                                                                                                             [[appetizer, platter, special, lunch]]
# 5                                                                          [[chili, cup, single, cheeseburger, onion, pickle, relish, vanilla, far]]
# 6   [[saturday, dec, ride, patco, silver, sleigh, santa, elf, decorated, train, center, city], [train, leave, lindenwold, make, stop], [great, kid]]
# 7                                                                                    [[probably, best, place, cool, spring, area, watch, game, eat]]
# 8                                                                                                                                           [[taco]]
# 9                                                                                 [[starbucks, substitute, boring, downtown, tampa], [ugh], [never]]
# 10                                                                                                                         [[order, tortilla, soup]]
# 11                                                                                                            [[good, definitely, coming, back], []]
# 12                                                                                                                          [[hotlight, must, stop]]
# 13                                                                                                                            [[let, u, go, yankee]]
# 14                                                                                                                        [[basically, food, rally]]
# 15                                          [[not, go, dinner], [close, really, yvonne, l], [negative, star, restaurant, not, never, intended, eat]]
# 16                                                                                                              [[min, take], [right, right, tight]]
# 17                                         [[got, grilled, chicken, entree], [wa, delicious, wa, small, portion], [like, environment, sure, though]]
# 18                                                                                                          [[bomb], [love, dish], [try, like, lol]]
# 19                                                                                                               [[helping, mona, find, new, phone]]
# 20                                                                                                                      [[yes, eating], [breakfast]]
# 21                                                                                                                     [[order, crispy, bake, good]]
# 22                                                                                                                             [[crepe, please], []]
# 23                                        [[pimento, cheese, taste, great, large, portion, starter, great, sharing], [fried, pickle, also, awesome]]
# 24                          [[not, good, used, place, west, coast, called, carl, applicable, please, not, come, turkey, burger], [no, longer, menu]]
# 25                                                                                                                             [[everything, yummy]]
# 26                                                                                                                       [[allow, time, wait, food]]
# 27                                                                                              [[look, like, mini, burger, similar, white, castle]]
# 28                                                                                                                                     [[icky, tap]]
# 29                                                                                                  [[great, breakfast, buffet, open, public, also]]

# %% [markdown]
# #### Rename text column
# Less confusing than 'text' we use in the user reviews file.

# %%
# Rename text column
tips_renamed_df = tips_df.rename(columns={'text':'tip'})
tips_renamed_df.shape

# %% [markdown]
# #### Find duplicates

# %%
duplicates = tips_renamed_df.duplicated()
tips_renamed_df[duplicates].shape

# %% [markdown]
# #### Drop duplicates and keep first occurrence

# %%
tips_no_dups_df = tips_renamed_df.drop_duplicates(keep='first').copy()
tips_no_dups_df.shape

# %%
duplicates = tips_no_dups_df.duplicated()
tips_no_dups_df[duplicates].shape

# %% [markdown]
# #### Calculate Tip length

# %%
# Tips length analysis
tips_no_dups_df["tip_length"] = tips_no_dups_df.tip.apply(lambda t: len(t))
tips_no_dups_df[['tip', 'tip_length']].sort_values('tip_length', ascending=False).head()

# %%
tips_lemmatized_df.columns
